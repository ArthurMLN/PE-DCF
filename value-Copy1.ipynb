# %%
import sqlite3
import pandas as pd
from datetime import datetime, timedelta
# 定义数据库路径
db_path = r"Y:\YZ\plan.db"
db_path = "plan.db"
# 定义日期比较基准,上半年的就要看下一年的eps了，下半年的还看当年的。
cutoff_date = datetime.strptime("2025-09-30", "%Y-%m-%d")
# 查询语句
query = """
SELECT Symbol, Low_PE, High_PE, FEPS,FFEPS,YOYGrowth,EPSY,PEG,PEG5
FROM CValue
WHERE "FEPS" IS NOT NULL AND Low_PE IS NOT NULL AND High_PE IS NOT NULL;
"""

try:
    # 连接到数据库
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()

        # 检查数据库中是否存在表 CValue
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()
        if ('CValue',) not in tables:
            raise Exception("Table 'CValue' does not exist in the database.")

        # 执行查询
        cursor.execute(query)
        rows = cursor.fetchall()

        # 初始化结果和 symbol_list
        results = []
        symbol_list = []
        for row in rows:
            print (row)
            symbol, low_pe, high_pe, feps,ffeps,growth,epsy,PEG,PEG5 = row
            # 检查 EPSY 日期是否早于 cutoff_date
            use_ffeps = False
            if epsy:
                try:
                    epsy_date = datetime.strptime(epsy, "%Y-%m-%d")
                    if epsy_date <= cutoff_date:
                        use_ffeps = True
                        effective_epsy = epsy_date.replace(year=epsy_date.year + 1)
                    else:
                        effective_epsy= epsy_date
                except ValueError:
                    print(f"Invalid EPSY format for {symbol}: {epsy}. Skipping...")
                    continue

            # 根据条件选择 FEPS 或 FFEPS
            effective_eps = ffeps if use_ffeps else feps
            
            low_price = low_pe * effective_eps
            high_price = high_pe * effective_eps
            results.append({
                "Symbol": symbol,
                "LowPrice": low_price,
                "HighPrice": high_price,
                "Growth": growth,
                "effective_eps":effective_eps,
                "effective_epsy":effective_epsy,
                "PEG":PEG,
                "PEG5":PEG5,
            })
            symbol_list.append(symbol)  # 将 Symbol 添加到列表

        # 将结果转换为 DataFrame 并显示
        df_results = pd.DataFrame(results)
        print(df_results)  # 打印结果
        # <<< --- INSERT THIS CODE BLOCK after df_results is created and printed --- >>>
        if not df_results.empty:
            print("\n--- Updating database from DataFrame ---")
            update_sql = "UPDATE CValue SET LowPrice = ?, HighPrice = ? WHERE Symbol = ?"
            updated_count = 0
            failed_updates = 0

            for index, df_row in df_results.iterrows():
                symbol_to_update = df_row["Symbol"]
                # Ensure the columns exist in your df_results
                new_low_price = df_row.get("LowPrice") 
                new_high_price = df_row.get("HighPrice")

                # Check if prices are valid numbers (not None or NaN from calculation issues)
                if new_low_price is None or pd.isna(new_low_price) or \
                   new_high_price is None or pd.isna(new_high_price):
                    print(f"Skipping update for {symbol_to_update}: Invalid LowPrice or HighPrice values.")
                    failed_updates += 1
                    continue
                
                try:
                    cursor.execute(update_sql, (new_low_price, new_high_price, symbol_to_update))
                    if cursor.rowcount > 0:
                        updated_count += 1
                    # else:
                        # This means the symbol was not found in the DB for update,
                        # or the values were already the same and the DB optimized it.
                        # print(f"Symbol '{symbol_to_update}' not found for update or no change needed.")
                        # Depending on strictness, you might count this as a failed update too.
                except sqlite3.Error as e_update:
                    print(f"Error updating {symbol_to_update}: {e_update}")
                    failed_updates += 1
            
            if updated_count > 0:
                conn.commit() # Commit all successful updates
                print(f"\nSuccessfully committed updates for {updated_count} symbols.")
            elif failed_updates == 0 and updated_count == 0 and not df_results.empty:
                print("\nNo symbols required an update (values may have been current) or symbols not found.")
            
            if failed_updates > 0:
                print(f"Failed to process updates for {failed_updates} symbols.")

        elif results: # If results list was populated but df_results ended up empty (e.g. all rows filtered)
            print("\nDataFrame df_results is empty though initial data was processed. No updates to perform.")
        else: # If 'results' list itself was empty
            print("\nNo data was processed into DataFrame. No updates to perform.")
        # <<< --- END OF INSERTED CODE BLOCK --- >>>
        print("Symbol List:", symbol_list)  # 打印 symbol_list
except Exception as e:
    print("Error:", str(e))
# Out:
# ('MSFT', 23.5, 31.5, 13.38589, 15.08797, 12.7154787615915, '2025-06-30', 2.7004018612521143, 2.5210647954855667)
# ('AAPL', 20.0, 30, 7.1942, 7.87147, 9.414111367490479, '2025-09-30', 2.958421309079097, 2.9255155121457554)
# ('PYPL', 15.0, 25, 5.07164, 5.61028, 10.620627647072741, '2025-12-31', 1.3264425219070253, 1.216550269466204)
# ('CAT', 11.2, 24.7, 18.72018, 21.23595, 13.43881308833569, '2025-12-31', 1.3970275502132545, 1.9741737251915281)
# ('CVX', 10.0, 12, 7.77554, 9.45851, 21.64441312114657, '2025-12-31', 0.8186420435301877, 2.8858349492682467)
# ('V', 20.0, 30, 11.33959, 12.73334, 12.291008757812238, '2025-09-30', 2.576825112107622, 2.5833425791407247)
# ('META', 16.9, 34.4, 25.55818, 28.54458, 11.684713074248636, '2025-12-31', 2.1459282078757034, 1.3430399243151672)
# ('HON', 16.2, 22.4, 10.36748, 11.37384, 9.706891163522853, '2025-12-31', 2.249493223101079, 2.8580609803304196)
# ('UNH', 15.3, 24.6, 23.45207, 27.69824, 18.105736508547007, '2025-12-31', 0.6881731065878192, 1.7475288836111205)
# ('GS', 6.4, 13.6, 44.82901, 50.12905, 11.822790643826403, '2025-12-31', 1.160708221070029, 0.7272289505182368)
# ('HD', 17.2, 28.7, 15.15522, 14.99363, -1.0662332846372429, '2025-01-31', 5.932902762827399, 5.613218082538652)
# ('WMT', 18.0, 23.6, 2.48997, 2.61687, 5.096446945143918, '2025-01-31', 7.681245074862095, 4.264385402688746)
# ('GOOGL', 22.0, 36, 9.57711, 10.16132, 6.100065677432969, '2025-12-31', 2.954845004364866, 1.0943988216915843)
# ('NFLX', 30.0, 60, 25.64535, 30.85535, 20.315573778482264, '2025-12-31', 2.3173800383877152, 1.7941655923265127)
# ('TSLA', 30.0, 50, 1.90808, 2.87878, 50.87312900926585, '2025-12-31', 3.696662202534254, 7.522430925328078)
# ('FDX', 9.2, 22.3, 18.12757, 20.49791, 13.075883860881532, '2025-05-31', 0.9273353189837736, 0.917226091613113)
# ('MA', 20.0, 30, 15.93042, 18.62785, 16.932573026950944, '2025-12-31', 2.1270987569649638, 2.4925436012350057)
# ('ILMN', 46.8, 56.4, 4.22916, 4.70442, 11.237692591436586, '2025-12-31', 1.7260026090981795, 1.1827004105526118)
# 3      CAT  209.666016  462.388446  13.438813       18.72018     2025-12-31
# 4      CVX   77.755400   93.306480  21.644413        7.77554     2025-12-31
# ..     ...         ...         ...        ...            ...            ...
# 320     DD   85.229800  127.844700   9.426750        4.26149     2025-12-31
# 321    CRH   70.020265   95.799154  11.563627        5.71594     2025-12-31
# 322    ECL  187.437000  217.426920  12.603035        7.49748     2025-12-31
# 323    COP   98.504640  147.756960   8.251591        8.20872     2025-12-31
# 324    CCL   16.935373   34.056849  15.378581        1.86103     2025-11-30
#
#           PEG      PEG5
# 0    2.700402  2.521065
# 1    2.958421  2.925516
# 2    1.326443  1.216550
# 3    1.397028  1.974174
# 4    0.818642  2.885835
# ..        ...       ...
# 320  1.718486  1.349978
# 321  1.442274  1.145462
# 322       NaN       NaN
# 323       NaN       NaN
# 324  0.821017  1.262607
#
# [325 rows x 8 columns]
#
# --- Updating database from DataFrame ---
#
# Successfully committed updates for 325 symbols.
# Symbol List: ['MSFT', 'AAPL', 'PYPL', 'CAT', 'CVX', 'V', 'META', 'HON', 'UNH', 'GS', 'HD', 'WMT', 'GOOGL', 'NFLX', 'TSLA', 'FDX', 'MA', 'ILMN', 'TSM', 'CF', 'TMO', 'JNJ', 'XOM', 'BA', 'PG', 'DOW', 'VZ', 'DUK', 'ABBV', 'PM', 'BAC', 'MMM', 'MCD', 'AMGN', 'JPM', 'BLK', 'ISRG', 'GNRC', 'MNST', 'MTH', 'ABT', 'IBM', 'TXN', 'NEE', 'AXP', 'LMT', 'GE', 'INTC', 'T', 'KLAC', 'MSCI', 'NUE', 'LUV', 'ALK', 'X', 'CHTR', 'CL', 'ROK', 'DAL', 'UAL', 'AAL', 'WFC', 'C', 'SCHW', 'PNC', 'BK', 'MS', 'USB', 'LRCX', 'FCX', 'KMB', 'MDLZ', 'MO', 'NXPI', 'UPS', 'SBUX', 'GM', 'EA', 'PHM', 'DHI', 'QCOM', 'TMUS', 'LLY', 'MRK', 'EL', 'F', 'PH', 'BIIB', 'CMI', 'ROP', 'LITE', 'REGN', 'APD', 'CLX', 'ETN', 'UNP', 'PPG', 'TRV', 'WY', 'TSN', 'SPG', 'DIS', 'CVS', 'PEP', 'MCO', 'DE', 'AMAT', 'VMC', 'LOW', 'BBY', 'STX', 'WBA', 'SHOP', 'OKTA', 'NET', 'ZS', 'CRWD', 'NOW', 'TTD', 'DDOG', 'HUBS', 'TWLO', 'CRM', 'SAP', 'FTNT', 'ADSK', 'PANW', 'DBX', 'ADBE', 'ADP', 'ORCL', 'INTU', 'CSCO', 'ZM', 'MU', 'TER', 'QRVO', 'MRVL', 'AMKR', 'POWI', 'AMD', 'ENTG', 'NVDA', 'SLAB', 'LSCC', 'ASML', 'AKAM', 'UPST', 'PLTR', 'ABNB', 'U', 'MDT', 'KHC', 'MGA', 'D', 'YUM', 'ALB', 'MOS', 'ETSY', 'EIX', 'O', 'VRTX', 'PFE', 'EXPE', 'BKNG', 'UBER', 'MAR', 'RCL', 'XYZ', 'EBAY', 'MPW', 'AMT', 'HAS', 'AMZN', 'ENPH', 'CDNS', 'CMG', 'KO', 'RTX', 'SHW', 'ALGN', 'DXCM', 'CME', 'SPGI', 'WM', 'LIN', 'NOC', 'LYFT', 'GOOS', 'SE', 'BIDU', 'TJX', 'TGT', 'KKR', 'A', 'ON', 'SNAP', 'DHR', 'BTU', 'CENX', 'AA', 'SCCO', 'TGB', 'BKR', 'SLB', 'ZIM', 'NEM', 'IAG', 'MCHP', 'PBI', 'KGC', 'VIRT', 'ALL', 'MFC', 'VEON', 'EGO', 'NGD', 'PAAS', 'SVM', 'GLDD', 'ET', 'MPLX', 'WES', 'EPD', 'KMI', 'APO', 'WBS', 'EWBC', 'SO', 'SKYW', 'MCY', 'VIST', 'TS', 'JD', 'BABA', 'SWKS', 'KRC', 'OXY', 'PPC', 'SMG', 'CTVA', 'ADM', 'BG', 'DAR', 'INGR', 'CAG', 'KLG', 'KR', 'ALEX', 'LEN', 'TOL', 'TTWO', 'HSY', 'CPAY', 'ARM', 'ANET', 'PINS', 'MELI', 'MTCH', 'ZTS', 'TRIP', 'NCLH', 'SU', 'NKE', 'SHEL', 'IMO', 'PR', 'CTRA', 'NRG', 'COF', 'COST', 'LULU', 'SNOW', 'ROST', 'PDD', 'XPEV', 'NIO', 'COIN', 'CB', 'ITW', 'CBOE', 'DASH', 'MPWR', 'ENB', 'FSLR', 'LI', 'LVS', 'AN', 'NVO', 'SNPS', 'CCI', 'STT', 'CI', 'CFLT', 'TEAM', 'FTK', 'SXT', 'IDXX', 'AVGO', 'FMS', 'DLTR', 'MDB', 'EXEL', 'DELL', 'BX', 'FAST', 'DPZ', 'ACN', 'DG', 'ULTA', 'RH', 'DOCU', 'CHWY', 'KMX', 'M', 'ADI', 'CSX', 'EQIX', 'CNI', 'GILD', 'DD', 'CRH', 'ECL', 'COP', 'CCL']

# %%
import requests
from datetime import datetime
import pytz  # For timezone conversion
import time
# %run constant.ipynb
import sqlite3
from datetime import datetime

# Function to insert lastPrice into the database
def update_last_price(data, db_path='plan.db'):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    try:
        for item in data:
            symbol = item.get('symbol')
            last_price = item.get('lastPrice')
            print (symbol,last_price)
            # 检查 symbol 是否存在于数据库中
            cursor.execute("""
                SELECT COUNT(*) FROM EMA169 WHERE symbol = ?
            """, (symbol,))
            exists = cursor.fetchone()[0]

            if exists:
                # 如果 symbol 存在，则更新 last_price
                cursor.execute("""
                    UPDATE EMA169
                    SET last_price = ?
                    WHERE symbol = ?
                """, (last_price, symbol))
            else:
                print(f"Symbol '{symbol}' does not exist in the EMA169 table and was not updated.")

        conn.commit()
        print("Last prices updated successfully.")
    except Exception as e:
        print(f"Error occurred: {e}")
    finally:
        conn.close()


# Set up Houston timezone
houston_tz = pytz.timezone('America/Chicago')

def convert_to_houston_time(timestamp):
    """Converts UNIX timestamp (milliseconds) to Houston time."""
    # Convert from milliseconds to seconds
    utc_time = datetime.utcfromtimestamp(timestamp / 1000)
    # Convert to Houston time
    houston_time = utc_time.replace(tzinfo=pytz.utc).astimezone(houston_tz)
    return houston_time.strftime('%Y-%m-%d %H:%M:%S')  # Format the time as a string

# Fetch current data for a single symbol
def get_current_data(symbol, access_token):
    base_url = f'https://api.schwabapi.com/marketdata/v1/{symbol}/quotes'
    headers = {
        'accept': 'application/json',
        'Authorization': f'Bearer {access_token}'
    }
    
    response = requests.get(base_url, headers=headers)
    response.raise_for_status()  # Raise an error for bad responses
    data = response.json()
    
    #print (data)
    # Extract the needed data from the response
    symbol_data = data.get(symbol, {})
    last_price = symbol_data.get('regular', {}).get('regularMarketLastPrice', None)
    trade_time = symbol_data.get('regular', {}).get('regularMarketTradeTime', None)
    high_price = symbol_data.get('quote', {}).get('highPrice', None)
    low_price = symbol_data.get('quote', {}).get('lowPrice', None)
    open_price = symbol_data.get('quote', {}).get('openPrice', None)
    close_price = symbol_data.get('quote', {}).get('closePrice', None)
   
    # Convert trade_time to Houston time if available
    if trade_time:
        trade_time = convert_to_houston_time(trade_time)

    # Return a dictionary with the symbol, last price, and trade time
    return {'symbol': symbol, 'lastPrice': last_price,'high_price':high_price,'open_price':open_price,'close_price':close_price,'low_price':low_price,'datetime': trade_time}

# Fetch current data for a list of symbols
def get_current_data_for_symbols(symbols, access_token):
    results = []
    for symbol in symbols:
        # Fetch data for each symbol
        symbol_data = get_current_data(symbol, access_token)
        # Append the result to the list
        results.append(symbol_data)
        time.sleep(0.1)
    return results

# Example usage
access_token = get_new_tokens()  # Assuming you already have a function to get the access token
symbols = symbol_list  # List of symbols
current_price = get_current_data_for_symbols(symbols, access_token)

# Print the result
print(current_price)

if __name__ == "__main__":
    update_last_price(current_price, db_path='plan.db')
# Out:
# C:\Users\Rhino\AppData\Local\Temp\ipykernel_488\3283846029.py:49: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   utc_time = datetime.utcfromtimestamp(timestamp / 1000)
# [{'symbol': 'MSFT', 'lastPrice': 460.36, 'high_price': 461.68, 'open_price': 459.715, 'close_price': 458.68, 'low_price': 455.54, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'AAPL', 'lastPrice': 200.85, 'high_price': 201.96, 'open_price': 199.37, 'close_price': 199.95, 'low_price': 196.78, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'PYPL', 'lastPrice': 70.28, 'high_price': 71.08, 'open_price': 70.96, 'close_price': 70.93, 'low_price': 69.52, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'CAT', 'lastPrice': 348.03, 'high_price': 353.24, 'open_price': 351.83, 'close_price': 351.79, 'low_price': 347.02, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'CVX', 'lastPrice': 136.7, 'high_price': 137.45, 'open_price': 136.88, 'close_price': 137.91, 'low_price': 135.21, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'V', 'lastPrice': 365.19, 'high_price': 367.04, 'open_price': 361.35, 'close_price': 362.4, 'low_price': 361.35, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'META', 'lastPrice': 647.49, 'high_price': 649.4099, 'open_price': 642.5, 'close_price': 645.05, 'low_price': 632.78, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'HON', 'lastPrice': 226.67, 'high_price': 227.02, 'open_price': 226.65, 'close_price': 225.19, 'low_price': 223.765, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'UNH', 'lastPrice': 301.91, 'high_price': 305.64, 'open_price': 297.97, 'close_price': 298.17, 'low_price': 295.8385, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'GS', 'lastPrice': 600.45, 'high_price': 603.6, 'open_price': 600.0, 'close_price': 601.86, 'low_price': 593.83, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'HD', 'lastPrice': 368.29, 'high_price': 369.64, 'open_price': 367.05, 'close_price': 368.29, 'low_price': 365.12, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'WMT', 'lastPrice': 98.72, 'high_price': 98.93, 'open_price': 96.96, 'close_price': 97.1, 'low_price': 96.6, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'GOOGL', 'lastPrice': 171.74, 'high_price': 172.205, 'open_price': 171.35, 'close_price': 171.86, 'low_price': 167.44, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'NFLX', 'lastPrice': 1207.23, 'high_price': 1211.81, 'open_price': 1198.33, 'close_price': 1184.86, 'low_price': 1180.925, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'TSLA', 'lastPrice': 346.46, 'high_price': 363.68, 'open_price': 355.52, 'close_price': 358.43, 'low_price': 345.29, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'FDX', 'lastPrice': 218.1, 'high_price': 219.47, 'open_price': 219.47, 'close_price': 220.26, 'low_price': 215.93, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'MA', 'lastPrice': 585.6, 'high_price': 585.6, 'open_price': 576.775, 'close_price': 577.78, 'low_price': 576.51, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'ILMN', 'lastPrice': 82.24, 'high_price': 83.72, 'open_price': 83.46, 'close_price': 84.28, 'low_price': 81.19, 'datetime': '2025-05-30 15:00:00'}, {'symbol': 'TSM', 'lastPrice': 193.32, 'high_price': 195.91, 'open_price': 195.77, 'close_price': 197.15, 'low_price': 190.56, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'CF', 'lastPrice': 90.71, 'high_price': 90.78, 'open_price': 89.97, 'close_price': 90.11, 'low_price': 89.23, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'TMO', 'lastPrice': 402.82, 'high_price': 405.44, 'open_price': 401.71, 'close_price': 403.75, 'low_price': 397.315, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'JNJ', 'lastPrice': 155.21, 'high_price': 155.71, 'open_price': 153.9, 'close_price': 153.58, 'low_price': 153.22, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'XOM', 'lastPrice': 102.3, 'high_price': 102.39, 'open_price': 102.16, 'close_price': 102.69, 'low_price': 101.185, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'BA', 'lastPrice': 207.32, 'high_price': 207.7, 'open_price': 206.77, 'close_price': 208.18, 'low_price': 204.35, 'datetime': '2025-05-30 18:00:00'}, {'symbol': 'PG', 'lastPrice': 169.89, 'high_price': 170.99, 'open_price': 168.75, 'close_price': 168.5 ...
# MSFT 460.36
# AAPL 200.85
# PYPL 70.28
# CAT 348.03
# CVX 136.7
# V 365.19
# META 647.49
# HON 226.67
# UNH 301.91
# GS 600.45
# HD 368.29
# WMT 98.72
# GOOGL 171.74
# NFLX 1207.23
# TSLA 346.46
# FDX 218.1
# MA 585.6
# ILMN 82.24
# TSM 193.32
# CF 90.71
# TMO 402.82
# JNJ 155.21
# XOM 102.3
# BA 207.32
# PG 169.89
# DOW 27.74
# VZ 43.96
# DUK 117.72
# ABBV 186.11
# PM 180.59
# BAC 44.13
# MMM 148.35
# MCD 313.85
# AMGN 288.18
# JPM 264.0
# BLK 979.89
# ISRG 552.34
# GNRC 122.13
# MNST 63.95
# MTH 63.61
# ABT 133.58
# IBM 259.06
# TXN 182.85
# NEE 70.64
# AXP 294.05
# LMT 482.38
# GE 245.91
# INTC 19.55
# T 27.8
# KLAC 756.88
# MSCI 564.02
# NUE 109.36
# LUV 33.38
# ALK 50.93
# X 53.82
# CHTR 396.27
# CL 92.94
# ROK 315.55
# DAL 48.39
# UAL 79.445
# AAL 11.41
# WFC 74.78
# C 75.32
# SCHW 88.34
# PNC 173.81
# BK 88.61
# SWKS 69.03
# KRC 32.2
# OXY 40.78
# PPC 49.16
# SMG 59.56
# CTVA 70.8
# ADM 48.27
# BG 78.15
# DAR 31.16
# INGR 139.12
# CAG 22.89
# KLG 16.92
# KR 68.23
# ALEX 17.91
# LEN 106.08
# TOL 104.25
# TTWO 226.28
# HSY 160.69
# CPAY 325.11
# ARM 124.54
# ANET 86.64
# PINS 31.11
# MELI 2563.29
# MTCH 29.94
# ZTS 168.63
# TRIP 14.24
# NCLH 17.65
# SU 35.55
# NKE 60.59
# SHEL 66.22
# IMO 71.35
# PR 12.61
# CTRA 24.31
# NRG 155.9
# COF 189.15
# COST 1040.18
# LULU 316.67
# SNOW 205.67
# ROST 140.09
# PDD 96.51
# XPEV 19.31
# NIO 3.54
# COIN 246.62
# CB 297.2
# ITW 245.08
# CBOE 229.12
# DASH 208.65
# MPWR 661.9
# ENB 46.48
# FSLR 158.08
# LI 28.34
# LVS 41.16
# AN 183.85
# NVO 71.5
# SNPS 463.98
# CCI 100.35
# STT 96.28
# CI 316.64
# CFLT 23.03
# TEAM 207.63
# FTK 14.67
# SXT 94.53
# IDXX 513.36
# AVGO 242.07
# FMS 28.4
# DLTR 90.26
# MDB 188.83
# EXEL 43.04
# DELL 111.27
# BX 138.76
# FAST 41.34
# DPZ 473.82
# ACN 316.82
# DG 97.25
# ULTA 471.46
# RH 181.11
# DOCU 88.61
# CHWY 45.25
# KMX 64.46
# M 11.89
# ADI 213.98
# CSX 31.59
# EQIX 888.82
# CNI 104.94
# GILD 110.08
# DD 66.8
# CRH 91.16
# ECL 265.62
# Symbol 'ECL' does not exist in the EMA169 table and was not updated.
# COP 85.35
# Symbol 'COP' does not exist in the EMA169 table and was not updated.
# CCL 23.22
# Last prices updated successfully.

# %%
#这段是用上一段获得的last price 计算最新的PEG
import sqlite3

def calculate_and_update_peg_from_cvalue():
    # Connect to the SQLite database
    db_path = "plan.db"
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()

    try:
        # Fetch all symbols from CValue
        cursor.execute("SELECT Symbol FROM CValue")
        symbols = [row[0] for row in cursor.fetchall()]

        for symbol in symbols:
            # Fetch last_price from EMA169 for the current symbol
            cursor.execute("SELECT last_price FROM EMA169 WHERE symbol = ?", (symbol,))
            row_ema169 = cursor.fetchone()

            if row_ema169 is None:
                print(f"Symbol {symbol} not found in EMA169.")
                continue

            last_price = row_ema169[0]

            if last_price is None or last_price <= 0:
                print(f"Invalid last_price value for symbol {symbol}.")
                continue

            # Fetch relevant data from CValue for the symbol
            cursor.execute("SELECT FEPS, YOYGrowth, Growth5Y FROM CValue WHERE Symbol = ?", (symbol,))
            row_cvalue = cursor.fetchone()

            if row_cvalue is None:
                print(f"Symbol {symbol} not found in CValue.")
                continue

            feps, yoy_growth, growth_5y = row_cvalue

            # Ensure data validity
            if feps is None or feps <= 0:
                print(f"Invalid FEPS value for symbol {symbol}.")
                continue

            if yoy_growth is None or yoy_growth <= 0:
                print(f"Invalid YOYGrowth value for symbol {symbol}.")
                continue

            if growth_5y is None or growth_5y <= 0:
                print(f"Invalid Growth5Y value for symbol {symbol}.")
                continue

            # Calculate PEG and PEG5
            peg = last_price / feps / yoy_growth
            peg5 = last_price / feps / growth_5y

            # Update the database with the calculated values
            cursor.execute(
                "UPDATE CValue SET PEG = ?, PEG5 = ? WHERE Symbol = ?",
                (peg, peg5, symbol)
            )
            print(f"PEG and PEG5 for symbol {symbol} updated successfully.")

        # Commit all updates to the database
        connection.commit()

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        # Close the database connection
        connection.close()

# Example usage
if __name__ == "__main__":
    calculate_and_update_peg_from_cvalue()
# Out:
# PEG and PEG5 for symbol MSFT updated successfully.
# PEG and PEG5 for symbol AAPL updated successfully.
# PEG and PEG5 for symbol PYPL updated successfully.
# PEG and PEG5 for symbol CAT updated successfully.
# PEG and PEG5 for symbol CVX updated successfully.
# PEG and PEG5 for symbol V updated successfully.
# PEG and PEG5 for symbol META updated successfully.
# PEG and PEG5 for symbol HON updated successfully.
# PEG and PEG5 for symbol UNH updated successfully.
# PEG and PEG5 for symbol GS updated successfully.
# Invalid YOYGrowth value for symbol HD.
# PEG and PEG5 for symbol WMT updated successfully.
# PEG and PEG5 for symbol GOOGL updated successfully.
# PEG and PEG5 for symbol NFLX updated successfully.
# PEG and PEG5 for symbol TSLA updated successfully.
# PEG and PEG5 for symbol FDX updated successfully.
# PEG and PEG5 for symbol MA updated successfully.
# PEG and PEG5 for symbol ILMN updated successfully.
# PEG and PEG5 for symbol TSM updated successfully.
# Invalid YOYGrowth value for symbol CF.
# PEG and PEG5 for symbol TMO updated successfully.
# PEG and PEG5 for symbol JNJ updated successfully.
# PEG and PEG5 for symbol XOM updated successfully.
# Invalid FEPS value for symbol BA.
# PEG and PEG5 for symbol PG updated successfully.
# PEG and PEG5 for symbol DOW updated successfully.
# PEG and PEG5 for symbol VZ updated successfully.
# PEG and PEG5 for symbol DUK updated successfully.
# PEG and PEG5 for symbol ABBV updated successfully.
# PEG and PEG5 for symbol PM updated successfully.
# PEG and PEG5 for symbol BAC updated successfully.
# PEG and PEG5 for symbol MMM updated successfully.
# PEG and PEG5 for symbol MCD updated successfully.
# PEG and PEG5 for symbol AMGN updated successfully.
# PEG and PEG5 for symbol JPM updated successfully.
# PEG and PEG5 for symbol BLK updated successfully.
# PEG and PEG5 for symbol ISRG updated successfully.
# PEG and PEG5 for symbol GNRC updated successfully.
# PEG and PEG5 for symbol MNST updated successfully.
# PEG and PEG5 for symbol MTH updated successfully.
# PEG and PEG5 for symbol ABT updated successfully.
# PEG and PEG5 for symbol IBM updated successfully.
# PEG and PEG5 for symbol TXN updated successfully.
# PEG and PEG5 for symbol NEE updated successfully.
# PEG and PEG5 for symbol AXP updated successfully.
# PEG and PEG5 for symbol LMT updated successfully.
# PEG and PEG5 for symbol GE updated successfully.
# PEG and PEG5 for symbol INTC updated successfully.
# PEG and PEG5 for symbol T updated successfully.
# PEG and PEG5 for symbol KLAC updated successfully.
# PEG and PEG5 for symbol MSCI updated successfully.
# PEG and PEG5 for symbol NUE updated successfully.
# PEG and PEG5 for symbol LUV updated successfully.
# Invalid Growth5Y value for symbol ALK.
# Invalid Growth5Y value for symbol X.
# PEG and PEG5 for symbol CHTR updated successfully.
# PEG and PEG5 for symbol CL updated successfully.
# PEG and PEG5 for symbol ROK updated successfully.
# PEG and PEG5 for symbol DAL updated successfully.
# PEG and PEG5 for symbol UAL updated successfully.
# Invalid Growth5Y value for symbol AAL.
# PEG and PEG5 for symbol WFC updated successfully.
# PEG and PEG5 for symbol C updated successfully.
# PEG and PEG5 for symbol SCHW updated successfully.
# PEG and PEG5 for symbol PNC updated successfully.
# PEG and PEG5 for symbol BK updated successfully.
# PEG and PEG5 for symbol MS updated successfully.
# PEG and PEG5 for symbol USB updated successfully.
# PEG and PEG5 for symbol LRCX updated successfully.
# PEG and PEG5 for symbol FCX updated successfully.
# PEG and PEG5 for symbol KMB updated successfully.
# PEG and PEG5 for symbol MDLZ updated successfully.
# PEG and PEG5 for symbol MO updated successfully.
# PEG and PEG5 for symbol NXPI updated successfully.
# PEG and PEG5 for symbol UPS updated successfully.
# PEG and PEG5 for symbol SBUX updated successfully.
# PEG and PEG5 for symbol GM updated successfully.
# PEG and PEG5 for symbol EA updated successfully.
# PEG and PEG5 for symbol PHM updated successfully.
# PEG and PEG5 for symbol DHI updated successfully.
# PEG and PEG5 for symbol QCOM updated successfully.
# PEG and PEG5 for symbol TMUS updated successfully.
# PEG and PEG5 for symbol LLY updated successfully.
# PEG and PEG5 for symbol MRK updated successfully.
# PEG and PEG5 for symbol EL updated successfully.
# PEG and PEG5 for symbol F updated successfully.
# PEG and PEG5 for symbol PH updated successfully.
# PEG and PEG5 for symbol BIIB updated successfully.
# PEG and PEG5 for symbol CMI updated successfully.
# PEG and PEG5 for symbol ROP updated successfully.
# PEG and PEG5 for symbol LITE updated successfully.
# PEG and PEG5 for symbol REGN updated successfully.
# PEG and PEG5 for symbol APD updated successfully.
# Invalid YOYGrowth value for symbol CLX.
# PEG and PEG5 for symbol ETN updated successfully.
# PEG and PEG5 for symbol UNP updated successfully.
# PEG and PEG5 for symbol PPG updated successfully.
# PEG and PEG5 for symbol TRV updated successfully.
# Invalid Growth5Y value for symbol WY.
# PEG and PEG5 for symbol TSN updated successfully.
# PEG and PEG5 for symbol SPG updated successfully.
# PEG and PEG5 for symbol DIS updated successfully.
# PEG and PEG5 for symbol CVS updated successfully.
# PEG and PEG5 for symbol PEP updated successfully.
# PEG and PEG5 for symbol MCO updated successfully.
# PEG and PEG5 for symbol DE updated successfully.
# PEG and PEG5 for symbol AMAT updated successfully.
# PEG and PEG5 for symbol VMC updated successfully.
# PEG and PEG5 for symbol LOW updated successfully.
# PEG and PEG5 for symbol BBY updated successfully.
# PEG and PEG5 for symbol STX updated successfully.
# Invalid YOYGrowth value for symbol WBA.
# PEG and PEG5 for symbol SHOP updated successfully.
# PEG and PEG5 for symbol OKTA updated successfully.
# PEG and PEG5 for symbol NET updated successfully.
# PEG and PEG5 for symbol ZS updated successfully.
# Invalid YOYGrowth value for symbol CRWD.
# PEG and PEG5 for symbol NOW updated successfully.
# PEG and PEG5 for symbol TTD updated successfully.
# PEG and PEG5 for symbol DDOG updated successfully.
# PEG and PEG5 for symbol HUBS updated successfully.
# PEG and PEG5 for symbol TWLO updated successfully.
# PEG and PEG5 for symbol CRM updated successfully.
# PEG and PEG5 for symbol SAP updated successfully.
# PEG and PEG5 for symbol FTNT updated successfully.
# PEG and PEG5 for symbol ADSK updated successfully.
# PEG and PEG5 for symbol PANW updated successfully.
# PEG and PEG5 for symbol DBX updated successfully.
# PEG and PEG5 for symbol ADBE updated successfully.
# PEG and PEG5 for symbol ADP updated successfully.
# PEG and PEG5 for symbol ORCL updated successfully.
# PEG and PEG5 for symbol INTU updated successfully.
# PEG and PEG5 for symbol CSCO updated successfully.
# PEG and PEG5 for symbol ZM updated successfully.
# PEG and PEG5 for symbol MU updated successfully.
# PEG and PEG5 for symbol TER updated successfully.
# PEG and PEG5 for symbol QRVO updated successfully.
# PEG and PEG5 for symbol MRVL updated successfully.
# PEG and PEG5 for symbol AMKR updated successfully.
# PEG and PEG5 for symbol POWI updated successfully.
# PEG and PEG5 for symbol AMD updated successfully.
# PEG and PEG5 for symbol ENTG updated successfully.
# PEG and PEG5 for symbol NVDA updated successfully.
# PEG and PEG5 for symbol SLAB updated successfully.
# PEG and PEG5 for symbol LSCC updated successfully.
# PEG and PEG5 for symbol ASML updated successfully.
# PEG and PEG5 for symbol AKAM updated successfully.
# PEG and PEG5 for symbol UPST updated successfully.
# PEG and PEG5 for symbol PLTR updated successfully.
# PEG and PEG5 for symbol ABNB updated successfully.
# Invalid Growth5Y value for symbol U.
# PEG and PEG5 for symbol MDT updated successfully.
# PEG and PEG5 for symbol KHC updated successfully.
# PEG and PEG5 for symbol MGA updated successfully.
# PEG and PEG5 for symbol D updated successfully.
# PEG and PEG5 for symbol YUM updated successfully.
# Invalid FEPS value for symbol ALB.
# Invalid YOYGrowth value for symbol MOS.
# PEG and PEG5 for symbol ETSY updated successfully.
# PEG and PEG5 for symbol EIX updated successfully.
# PEG and PEG5 for symbol O updated successfully.
# PEG and PEG5 for symbol VRTX updated successfully.
# PEG and PEG5 for symbol PFE updated successfully.
# PEG and PEG5 for symbol EXPE updated successfully.
# PEG and PEG5 for symbol BKNG updated successfully.
# PEG and PEG5 for symbol UBER updated successfully.
# PEG and PEG5 for symbol MAR updated successfully.
# PEG and PEG5 for symbol RCL updated successfully.
# PEG and PEG5 for symbol XYZ updated successfully.
# PEG and PEG5 for symbol EBAY updated successfully.
# Invalid FEPS value for symbol MPW.
# PEG and PEG5 for symbol AMT updated successfully.
# PEG and PEG5 for symbol HAS updated successfully.
# PEG and PEG5 for symbol AMZN updated successfully.
# PEG and PEG5 for symbol ENPH updated successfully.
# PEG and PEG5 for symbol CDNS updated successfully.
# PEG and PEG5 for symbol CMG updated successfully.
# PEG and PEG5 for symbol KO updated successfully.
# PEG and PEG5 for symbol RTX updated successfully.
# PEG and PEG5 for symbol SHW updated successfully.
# PEG and PEG5 for symbol ALGN updated successfully.
# PEG and PEG5 for symbol DXCM updated successfully.
# PEG and PEG5 for symbol CME updated successfully.
# PEG and PEG5 for symbol SPGI updated successfully.
# PEG and PEG5 for symbol WM updated successfully.
# PEG and PEG5 for symbol LIN updated successfully.
# PEG and PEG5 for symbol NOC updated successfully.
# PEG and PEG5 for symbol LYFT updated successfully.
# PEG and PEG5 for symbol GOOS updated successfully.
# PEG and PEG5 for symbol SE updated successfully.
# PEG and PEG5 for symbol BIDU updated successfully.
# PEG and PEG5 for symbol TJX updated successfully.
# PEG and PEG5 for symbol TGT updated successfully.
# PEG and PEG5 for symbol KKR updated successfully.
# PEG and PEG5 for symbol A updated successfully.
# PEG and PEG5 for symbol ON updated successfully.
# PEG and PEG5 for symbol SNAP updated successfully.
# PEG and PEG5 for symbol DHR updated successfully.
# Invalid Growth5Y value for symbol BTU.
# Invalid YOYGrowth value for symbol CENX.
# Invalid YOYGrowth value for symbol AA.
# Invalid YOYGrowth value for symbol SCCO.
# PEG and PEG5 for symbol TGB updated successfully.
# PEG and PEG5 for symbol BKR updated successfully.
# PEG and PEG5 for symbol SLB updated successfully.
# Invalid YOYGrowth value for symbol ZIM.
# PEG and PEG5 for symbol NEM updated successfully.
# PEG and PEG5 for symbol IAG updated successfully.
# PEG and PEG5 for symbol MCHP updated successfully.
# PEG and PEG5 for symbol PBI updated successfully.
# PEG and PEG5 for symbol KGC updated successfully.
# Invalid YOYGrowth value for symbol VIRT.
# PEG and PEG5 for symbol ALL updated successfully.
# PEG and PEG5 for symbol MFC updated successfully.
# PEG and PEG5 for symbol VEON updated successfully.
# PEG and PEG5 for symbol EGO updated successfully.
# PEG and PEG5 for symbol NGD updated successfully.
# PEG and PEG5 for symbol PAAS updated successfully.
# Invalid YOYGrowth value for symbol SVM.
# PEG and PEG5 for symbol GLDD updated successfully.
# PEG and PEG5 for symbol ET updated successfully.
# PEG and PEG5 for symbol MPLX updated successfully.
# Symbol TRGP not found in EMA169.
# PEG and PEG5 for symbol WES updated successfully.
# PEG and PEG5 for symbol EPD updated successfully.
# PEG and PEG5 for symbol KMI updated successfully.
# PEG and PEG5 for symbol APO updated successfully.
# PEG and PEG5 for symbol WBS updated successfully.
# PEG and PEG5 for symbol EWBC updated successfully.
# PEG and PEG5 for symbol SO updated successfully.
# PEG and PEG5 for symbol SKYW updated successfully.
# PEG and PEG5 for symbol MCY updated successfully.
# PEG and PEG5 for symbol VIST updated successfully.
# PEG and PEG5 for symbol TS updated successfully.
# PEG and PEG5 for symbol JD updated successfully.
# PEG and PEG5 for symbol BABA updated successfully.
# Invalid YOYGrowth value for symbol SWKS.
# Invalid YOYGrowth value for symbol KRC.
# PEG and PEG5 for symbol OXY updated successfully.
# Invalid YOYGrowth value for symbol PPC.
# PEG and PEG5 for symbol SMG updated successfully.
# PEG and PEG5 for symbol CTVA updated successfully.
# PEG and PEG5 for symbol ADM updated successfully.
# Invalid Growth5Y value for symbol BG.
# PEG and PEG5 for symbol DAR updated successfully.
# PEG and PEG5 for symbol INGR updated successfully.
# PEG and PEG5 for symbol CAG updated successfully.
# PEG and PEG5 for symbol KLG updated successfully.
# PEG and PEG5 for symbol KR updated successfully.
# PEG and PEG5 for symbol ALEX updated successfully.
# PEG and PEG5 for symbol LEN updated successfully.
# PEG and PEG5 for symbol TOL updated successfully.
# PEG and PEG5 for symbol TTWO updated successfully.
# PEG and PEG5 for symbol HSY updated successfully.
# PEG and PEG5 for symbol CPAY updated successfully.
# PEG and PEG5 for symbol ARM updated successfully.
# PEG and PEG5 for symbol ANET updated successfully.
# PEG and PEG5 for symbol PINS updated successfully.
# PEG and PEG5 for symbol MELI updated successfully.
# PEG and PEG5 for symbol MTCH updated successfully.
# PEG and PEG5 for symbol ZTS updated successfully.
# PEG and PEG5 for symbol TRIP updated successfully.
# PEG and PEG5 for symbol NCLH updated successfully.
# PEG and PEG5 for symbol SU updated successfully.
# Invalid YOYGrowth value for symbol NKE.
# PEG and PEG5 for symbol SHEL updated successfully.
# Invalid YOYGrowth value for symbol IMO.
# Invalid YOYGrowth value for symbol PR.
# PEG and PEG5 for symbol CTRA updated successfully.
# PEG and PEG5 for symbol NRG updated successfully.
# PEG and PEG5 for symbol COF updated successfully.
# PEG and PEG5 for symbol COST updated successfully.
# PEG and PEG5 for symbol LULU updated successfully.
# PEG and PEG5 for symbol SNOW updated successfully.
# PEG and PEG5 for symbol ROST updated successfully.
# PEG and PEG5 for symbol PDD updated successfully.
# Invalid FEPS value for symbol XPEV.
# Invalid FEPS value for symbol NIO.
# PEG and PEG5 for symbol COIN updated successfully.
# PEG and PEG5 for symbol CB updated successfully.
# PEG and PEG5 for symbol ITW updated successfully.
# PEG and PEG5 for symbol CBOE updated successfully.
# PEG and PEG5 for symbol DASH updated successfully.
# PEG and PEG5 for symbol MPWR updated successfully.
# PEG and PEG5 for symbol ENB updated successfully.
# PEG and PEG5 for symbol FSLR updated successfully.
# PEG and PEG5 for symbol LI updated successfully.
# PEG and PEG5 for symbol LVS updated successfully.
# PEG and PEG5 for symbol AN updated successfully.
# PEG and PEG5 for symbol NVO updated successfully.
# PEG and PEG5 for symbol SNPS updated successfully.
# PEG and PEG5 for symbol CCI updated successfully.
# PEG and PEG5 for symbol STT updated successfully.
# PEG and PEG5 for symbol CI updated successfully.
# PEG and PEG5 for symbol CFLT updated successfully.
# PEG and PEG5 for symbol TEAM updated successfully.
# PEG and PEG5 for symbol FTK updated successfully.
# PEG and PEG5 for symbol SXT updated successfully.
# PEG and PEG5 for symbol IDXX updated successfully.
# PEG and PEG5 for symbol AVGO updated successfully.
# PEG and PEG5 for symbol FMS updated successfully.
# Invalid YOYGrowth value for symbol DLTR.
# Invalid YOYGrowth value for symbol MDB.
# PEG and PEG5 for symbol EXEL updated successfully.
# PEG and PEG5 for symbol DELL updated successfully.
# PEG and PEG5 for symbol BX updated successfully.
# PEG and PEG5 for symbol FAST updated successfully.
# PEG and PEG5 for symbol DPZ updated successfully.
# PEG and PEG5 for symbol ACN updated successfully.
# Invalid YOYGrowth value for symbol DG.
# Invalid YOYGrowth value for symbol ULTA.
# PEG and PEG5 for symbol RH updated successfully.
# Invalid YOYGrowth value for symbol DOCU.
# PEG and PEG5 for symbol CHWY updated successfully.
# PEG and PEG5 for symbol KMX updated successfully.
# Invalid YOYGrowth value for symbol M.
# PEG and PEG5 for symbol ADI updated successfully.
# PEG and PEG5 for symbol CSX updated successfully.
# PEG and PEG5 for symbol EQIX updated successfully.
# PEG and PEG5 for symbol CNI updated successfully.
# PEG and PEG5 for symbol GILD updated successfully.
# PEG and PEG5 for symbol DD updated successfully.
# PEG and PEG5 for symbol CRH updated successfully.
# Symbol ECL not found in EMA169.
# Symbol COP not found in EMA169.
# PEG and PEG5 for symbol CCL updated successfully.

# %%
# 这段是用EMA表格里的数据比较现在的价格和EMA的关系
import sqlite3

def update_ema_notes(db_path):
    # 连接 SQLite 数据库
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()

    try:
        # 查询所有行
        cursor.execute("SELECT symbol, daily, weekly, monthly, last_price FROM EMA169")
        rows = cursor.fetchall()

        for row in rows:
            symbol, daily, weekly, monthly, last_price = row
            note = None

            # 条件 1: 完全空头排列的 EMA
            if daily < weekly < monthly:
                note = "short trend seq"

            # 条件 2: 下跌趋势
            if last_price < daily and last_price < weekly and last_price < monthly:
                if note:
                    note += "; down trend"
                else:
                    note = "down trend"
            if last_price > weekly:
                if note:
                    note += "; weekly up"
                else:
                    note = "weekly up"
            # 更新 note 列
            if note:
                cursor.execute("""
                    UPDATE EMA169
                    SET note = ?
                    WHERE symbol = ?
                """, (note, symbol))

        # 提交更改
        connection.commit()
        print("EMA notes updated successfully.")

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        # 关闭数据库连接
        connection.close()

# 示例用法
if __name__ == "__main__":
    update_ema_notes(db_path="plan.db")
# Out:
# EMA notes updated successfully.

# %%
import pandas as pd
import sqlite3

# CSV 文件路径
csv_file_path = "watch 2025-05-27.csv"

# SQLite 数据库路径
db_path = "plan.db" # 修改为实际数据库路径

# 表名
table_name = "CValue"

try:
    # 读取 CSV 文件
    data = pd.read_csv(csv_file_path)
    data_copy=data
    # 检查是否有 'Last Quarter Announce Date' 列
    if 'Last Quarter Announce Date' not in data.columns:
        raise KeyError("'Last Quarter Announce Date' column not found in the CSV file.")
    
    # 重命名列以匹配数据库字段
    data = data.rename(columns={"Last Quarter Announce Date": "ER_Date"})
    
    # 连接到 SQLite 数据库
    conn = sqlite3.connect(db_path)
    
    # 将数据更新到数据库
    for _, row in data.iterrows():
        symbol = row.get("Symbol", None)
        er_date = row.get("ER_Date", None)
        
        if symbol and er_date:
            # 使用 SQL 更新表
            query = f"""
            UPDATE {table_name}
            SET ER_Date = ?
            WHERE Symbol = ?;
            """
            conn.execute(query, (er_date, symbol))
    
    # 提交更改并关闭连接
    data = data_copy
    conn.commit()
    conn.close()
    print("Database updated successfully!")
    
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Database updated successfully!

# %%
# Add input for filtering by Sector
#selected_sector = input("Enter the Sector to filter: ")
selected_sector="Materials"
# Filter the DataFrame by the selected Sector
df_filtered = df_display[df_display['Sector'] == selected_sector]

# Highlight styling for the filtered DataFrame
def highlight_row(row):
    styles = [''] * len(row)

    # Growth column styling
    if row['Growth'] < 0:
        styles[row.index.get_loc('Growth')] = 'background-color: red; color: white'
    elif 0 <= row['Growth'] < 8:
        styles[row.index.get_loc('Growth')] = 'background-color: yellow'
    else:
        styles[row.index.get_loc('Growth')] = 'background-color: green; color: white'

    # LowDiff column styling
    if row['LowDiff'] is True:
        styles[row.index.get_loc('LowDiff')] = 'background-color: green; color: white'
    elif isinstance(row['LowDiff'], float):
        styles[row.index.get_loc('LowDiff')] = 'background-color: green' if row['LowDiff'] < row['HighDiff'] else 'background-color: yellow'
    elif row['LowDiff'] is None:
        styles[row.index.get_loc('LowDiff')] = 'background-color: red; color: white'

    # HighDiff column styling
    if row['HighDiff'] is True:
        styles[row.index.get_loc('HighDiff')] = 'background-color: red; color: white'
    elif isinstance(row['HighDiff'], float):
        styles[row.index.get_loc('HighDiff')] = 'background-color: green'
     
    # PEG styling
    if row['PEG'] > 1.5:
        styles[row.index.get_loc('PEG')] = 'background-color: red; color: white'
    elif isinstance(row['PEG'], float):
        styles[row.index.get_loc('PEG')] = 'background-color: green'
     # PEG styling
    if row['PEG5'] > 1.5:
        styles[row.index.get_loc('PEG5')] = 'background-color: red; color: white'
    elif isinstance(row['PEG'], float):
        styles[row.index.get_loc('PEG5')] = 'background-color: green'
    # INS（机构持股比例）高亮
    try:
        ins = float(row['INS'])
        if ins >= 80:
            styles[row.index.get_loc('INS')] = 'background-color: green; color: white'
        elif ins < 70:
            styles[row.index.get_loc('INS')] = 'background-color: red; color: white'
        else:
            styles[row.index.get_loc('INS')] = 'background-color: yellow; color: black'
    except:
        pass  # 若 INS 无法转换为 float，则跳过  
    # Quant Rating styling
    if row['Quant Rating'] > 4.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: green; color: white'
    elif 3.5 < row['Quant Rating'] <= 4.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: yellow'
    elif 2.5 <= row['Quant Rating'] <= 3.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: lightgray'
    else:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: red; color: white'

    # DCF styling
    if row['DCF'] == 'N':
        styles[row.index.get_loc('DCF')] = 'background-color: lightgray'
    else:
        if row['lastPrice'] <= row['DCF'] * (1+row['Growth']/100):
            styles[row.index.get_loc('DCF')] = 'background-color: green; color: white'
        else:
            styles[row.index.get_loc('DCF')] = 'background-color: red; color: white'

    # Last Quarter Announce Date styling
    announce_date = pd.to_datetime(row['Last Quarter Announce Date'], errors='coerce')
    if pd.notnull(announce_date):
        # Range for ±7 days around Last Quarter Announce Date
        range_start_1 = announce_date - timedelta(days=8)
        range_end_1 = announce_date + timedelta(days=8)
        
        # Range for ±7 days around Last Quarter Announce Date + 90 days
        range_start_2 = announce_date + timedelta(days=90 - 8)
        range_end_2 = announce_date + timedelta(days=90 + 8)
        
        if range_start_1 <= today <= range_end_1:  # Within ±7 days of Last Quarter Announce Date
            styles[row.index.get_loc('Last Quarter Announce Date')] = 'background-color: green; color: white'
        elif range_start_2 <= today <= range_end_2:  # Within ±7 days of Last Quarter Announce Date + 90 days
            styles[row.index.get_loc('Last Quarter Announce Date')] = 'background-color: yellow'
    return styles

# Apply styling to the filtered DataFrame
styled_table = df_filtered.style.apply(highlight_row, axis=1)

# Display the styled DataFrame
styled_table
#Industrials,Utilities,Financials,Information Technology,Consumer Discretionary,Health Care,Communication Services,Consumer Staples
# Out:
# <style type="text/css">
# #T_aad8d_row0_col3, #T_aad8d_row0_col5, #T_aad8d_row1_col3, #T_aad8d_row1_col7, #T_aad8d_row1_col8, #T_aad8d_row2_col3, #T_aad8d_row2_col5, #T_aad8d_row2_col7, #T_aad8d_row2_col17, #T_aad8d_row3_col3, #T_aad8d_row3_col5, #T_aad8d_row3_col8, #T_aad8d_row3_col17, #T_aad8d_row4_col3, #T_aad8d_row4_col5, #T_aad8d_row4_col8, #T_aad8d_row5_col3, #T_aad8d_row5_col7, #T_aad8d_row6_col3, #T_aad8d_row6_col7, #T_aad8d_row7_col3, #T_aad8d_row7_col8, #T_aad8d_row7_col17, #T_aad8d_row8_col3, #T_aad8d_row8_col8, #T_aad8d_row8_col17, #T_aad8d_row9_col3, #T_aad8d_row9_col8, #T_aad8d_row10_col3, #T_aad8d_row10_col17, #T_aad8d_row11_col7, #T_aad8d_row11_col8, #T_aad8d_row12_col5, #T_aad8d_row12_col7, #T_aad8d_row13_col3, #T_aad8d_row13_col8, #T_aad8d_row13_col17, #T_aad8d_row14_col3, #T_aad8d_row14_col5, #T_aad8d_row14_col17, #T_aad8d_row16_col3, #T_aad8d_row17_col8, #T_aad8d_row17_col17, #T_aad8d_row18_col3, #T_aad8d_row18_col17, #T_aad8d_row19_col3, #T_aad8d_row19_col17, #T_aad8d_row20_col8, #T_aad8d_row20_col17, #T_aad8d_row21_col3, #T_aad8d_row22_col3, #T_aad8d_row22_col17, #T_aad8d_row23_col3, #T_aad8d_row24_col5, #T_aad8d_row25_col3, #T_aad8d_row25_col17, #T_aad8d_row26_col7, #T_aad8d_row27_col3, #T_aad8d_row27_col17, #T_aad8d_row28_col17, #T_aad8d_row29_col8, #T_aad8d_row29_col17 {
#   background-color: green;
#   color: white;
# }
# #T_aad8d_row0_col7, #T_aad8d_row7_col7, #T_aad8d_row8_col5, #T_aad8d_row11_col3, #T_aad8d_row12_col3, #T_aad8d_row15_col3, #T_aad8d_row16_col5, #T_aad8d_row17_col7, #T_aad8d_row19_col5 {
#   background-color: yellow;
# }
# #T_aad8d_row0_col8, #T_aad8d_row0_col17, #T_aad8d_row1_col17, #T_aad8d_row2_col8, #T_aad8d_row3_col15, #T_aad8d_row4_col14, #T_aad8d_row5_col8, #T_aad8d_row5_col15, #T_aad8d_row5_col17, #T_aad8d_row6_col8, #T_aad8d_row7_col5, #T_aad8d_row7_col6, #T_aad8d_row9_col5, #T_aad8d_row9_col6, #T_aad8d_row9_col15, #T_aad8d_row9_col17, #T_aad8d_row10_col8, #T_aad8d_row11_col14, #T_aad8d_row11_col17, #T_aad8d_row12_col8, #T_aad8d_row12_col14, #T_aad8d_row12_col15, #T_aad8d_row13_col14, #T_aad8d_row13_col15, #T_aad8d_row14_col8, #T_aad8d_row14_col14, #T_aad8d_row14_col15, #T_aad8d_row15_col8, #T_aad8d_row15_col17, #T_aad8d_row16_col8, #T_aad8d_row16_col15, #T_aad8d_row17_col3, #T_aad8d_row17_col14, #T_aad8
# #T_aad8d_row3_col7, #T_aad8d_row4_col7, #T_aad8d_row8_col7, #T_aad8d_row9_col7, #T_aad8d_row10_col7, #T_aad8d_row13_col7, #T_aad8d_row14_col7, #T_aad8d_row15_col7, #T_aad8d_row16_col7, #T_aad8d_row18_col7, #T_aad8d_row19_col7, #T_aad8d_row20_col7, #T_aad8d_row21_col7, #T_aad8d_row22_col7, #T_aad8d_row23_col7, #T_aad8d_row23_col8, #T_aad8d_row24_col7, #T_aad8d_row24_col8, #T_aad8d_row25_col7, #T_aad8d_row26_col8, #T_aad8d_row27_col7, #T_aad8d_row28_col7 {
#   background-color: lightgray;
# }
# #T_aad8d_row4_col17, #T_aad8d_row6_col17, #T_aad8d_row12_col17, #T_aad8d_row16_col17, #T_aad8d_row23_col17, #T_aad8d_row24_col17, #T_aad8d_row26_col17 {
#   background-color: yellow;
#   color: black;
# }
# </style>
# <table id="T_aad8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aad8d_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_aad8d_level0_col1" class="col_heading level0 col1" >LowPrice</th>
#       <th id="T_aad8d_level0_col2" class="col_heading level0 col2" >HighPrice</th>
#       <th id="T_aad8d_level0_col3" class="col_heading level0 col3" >Growth</th>
#       <th id="T_aad8d_level0_col4" class="col_heading level0 col4" >lastPrice</th>
#       <th id="T_aad8d_level0_col5" class="col_heading level0 col5" >LowDiff</th>
#       <th id="T_aad8d_level0_col6" class="col_heading level0 col6" >HighDiff</th>
#       <th id="T_aad8d_level0_col7" class="col_heading level0 col7" >Quant Rating</th>
#       <th id="T_aad8d_level0_col8" class="col_heading level0 col8" >DCF</th>
#       <th id="T_aad8d_level0_col9" class="col_heading level0 col9" >Score</th>
#       <th id="T_aad8d_level0_col10" class="col_heading level0 col10" >Sector</th>
#       <th id="T_aad8d_level0_col11" class="col_heading level0 col11" >effective_epsy</th>
#       <th id="T_aad8d_level0_col12" class="col_heading level0 col12" >Last Quarter Announce Date</th>
#       <th id="T_aad8d_level0_col13" class="col_heading level0 col13" >EPS Revision Grade</th>
#       <th id="T_aad8d_level0_col14" class="col_heading level0 col14" >PEG</th>
#       <th id="T_aad8d_level0_col15" class="col_heading level0 col15" >PEG5</th>
#       <th id="T_aad8d_level0_col16" class="col_heading level0 col16" >EMA_Note</th>
#       <th id="T_aad8d_level0_col17" class="col_heading level0 col17" >INS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aad8d_level0_row0" class="row_heading level0 row0" >217</th>
#       <td id="T_aad8d_row0_col0" class="data row0 col0" >PAAS</td>
#       <td id="T_aad8d_row0_col1" class="data row0 col1" >29.200000</td>
#       <td id="T_aad8d_row0_col2" class="data row0 col2" >45.300000</td>
#       <td id="T_aad8d_row0_col3" class="data row0 col3" >26.600000</td>
#       <td id="T_aad8d_row0_col4" class="data row0 col4" >24.400000</td>
#       <td id="T_aad8d_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_aad8d_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_aad8d_row0_col7" class="data row0 col7" >4.500000</td>
#       <td id="T_aad8d_row0_col8" class="data row0 col8" >6.945440</td>
#       <td id="T_aad8d_row0_col9" class="data row0 col9" >5.500000</td>
#       <td id="T_aad8d_row0_col10" class="data row0 col10" >Materials</td>
#       <td id="T_aad8d_row0_col11" class="data row0 col11" >2025-12-31 00:00:00</td>
#       <td id="T_aad8d_row0_col12" class="data row0 col12" >5/7/2025</td>
#       <td id="T_aad8d_row0_col13" class="data row0 col13" >A-</td>
#       <td id="T_aad8d_row0_col14" class="data row0 col14" >0.600000</td>
#       <td id="T_aad8d_row0_col15" class="data row0

# %%
# Hardcoded list of symbols to filter by
selected_symbols = (['TRV','XYZ']+['AMD', 'NVDA','LRCX']+
                   ['UNH','CI','MRK']+
                   ['BABA']+
                   ['BKR']+
                   ['PAAS','SVM','NGD','NEM','SCCO','TGB','DD','VMC']+
                   ['D','NEE']+
                   ['UBER','ORCL']+
                   ['NVO'])# Replace with your desired symbols

# Filter the DataFrame by the selected symbols
df_filtered = df_display[df_display['Symbol'].isin(selected_symbols)]

# Highlight styling for the filtered DataFrame
def highlight_row(row):
    styles = [''] * len(row)

    # Growth column styling
    if row['Growth'] < 0:
        styles[row.index.get_loc('Growth')] = 'background-color: red; color: white'
    elif 0 <= row['Growth'] < 8:
        styles[row.index.get_loc('Growth')] = 'background-color: yellow'
    else:
        styles[row.index.get_loc('Growth')] = 'background-color: green; color: white'

    # LowDiff column styling
    if row['LowDiff'] is True:
        styles[row.index.get_loc('LowDiff')] = 'background-color: green; color: white'
    elif isinstance(row['LowDiff'], float):
        styles[row.index.get_loc('LowDiff')] = 'background-color: green' if row['LowDiff'] < row['HighDiff'] else 'background-color: yellow'
    elif row['LowDiff'] is None:
        styles[row.index.get_loc('LowDiff')] = 'background-color: red; color: white'

    # HighDiff column styling
    if row['HighDiff'] is True:
        styles[row.index.get_loc('HighDiff')] = 'background-color: red; color: white'
    elif isinstance(row['HighDiff'], float):
        styles[row.index.get_loc('HighDiff')] = 'background-color: green'
     
    # PEG styling
    if row['PEG'] > 1.5:
        styles[row.index.get_loc('PEG')] = 'background-color: red; color: white'
    elif isinstance(row['PEG'], float):
        styles[row.index.get_loc('PEG')] = 'background-color: green'
     # PEG styling
    if row['PEG5'] > 1.5:
        styles[row.index.get_loc('PEG5')] = 'background-color: red; color: white'
    elif isinstance(row['PEG'], float):
        styles[row.index.get_loc('PEG5')] = 'background-color: green'
    # INS（机构持股比例）高亮
    try:
        ins = float(row['INS'])
        if ins >= 80:
            styles[row.index.get_loc('INS')] = 'background-color: green; color: white'
        elif ins < 70:
            styles[row.index.get_loc('INS')] = 'background-color: red; color: white'
        else:
            styles[row.index.get_loc('INS')] = 'background-color: yellow; color: black'
    except:
        pass  # 若 INS 无法转换为 float，则跳过
    # Quant Rating styling
    if row['Quant Rating'] > 4.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: green; color: white'
    elif 3.5 < row['Quant Rating'] <= 4.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: yellow'
    elif 2.5 <= row['Quant Rating'] <= 3.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: lightgray'
    else:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: red; color: white'

    # DCF styling
    if row['DCF'] == 'N':
        styles[row.index.get_loc('DCF')] = 'background-color: lightgray'
    else:
        if row['lastPrice'] <= row['DCF'] * (1+row['Growth']/100):
            styles[row.index.get_loc('DCF')] = 'background-color: green; color: white'
        else:
            styles[row.index.get_loc('DCF')] = 'background-color: red; color: white'

    # Last Quarter Announce Date styling
    announce_date = pd.to_datetime(row['Last Quarter Announce Date'], errors='coerce')
    if pd.notnull(announce_date):
        # Range for ±7 days around Last Quarter Announce Date
        range_start_1 = announce_date - timedelta(days=8)
        range_end_1 = announce_date + timedelta(days=8)
        
        # Range for ±7 days around Last Quarter Announce Date + 90 days
        range_start_2 = announce_date + timedelta(days=90 - 8)
        range_end_2 = announce_date + timedelta(days=90 + 8)
        
        if range_start_1 <= today <= range_end_1:  # Within ±7 days of Last Quarter Announce Date
            styles[row.index.get_loc('Last Quarter Announce Date')] = 'background-color: green; color: white'
        elif range_start_2 <= today <= range_end_2:  # Within ±7 days of Last Quarter Announce Date + 90 days
            styles[row.index.get_loc('Last Quarter Announce Date')] = 'background-color: yellow'
    return styles

# Apply styling to the filtered DataFrame
styled_table = df_filtered.style.apply(highlight_row, axis=1)

# Display the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_3dd4d_row0_col3, #T_3dd4d_row0_col5, #T_3dd4d_row0_col7, #T_3dd4d_row0_col8, #T_3dd4d_row0_col17, #T_3dd4d_row1_col3, #T_3dd4d_row1_col5, #T_3dd4d_row1_col8, #T_3dd4d_row2_col3, #T_3dd4d_row2_col5, #T_3dd4d_row3_col3, #T_3dd4d_row3_col5, #T_3dd4d_row3_col7, #T_3dd4d_row3_col8, #T_3dd4d_row4_col3, #T_3dd4d_row4_col7, #T_3dd4d_row4_col8, #T_3dd4d_row5_col3, #T_3dd4d_row5_col5, #T_3dd4d_row5_col8, #T_3dd4d_row5_col17, #T_3dd4d_row6_col3, #T_3dd4d_row6_col5, #T_3dd4d_row6_col8, #T_3dd4d_row6_col17, #T_3dd4d_row7_col3, #T_3dd4d_row7_col8, #T_3dd4d_row8_col3, #T_3dd4d_row8_col8, #T_3dd4d_row8_col17, #T_3dd4d_row9_col3, #T_3dd4d_row9_col5, #T_3dd4d_row9_col8, #T_3dd4d_row10_col3, #T_3dd4d_row10_col5, #T_3dd4d_row10_col8, #T_3dd4d_row10_col17, #T_3dd4d_row11_col3, #T_3dd4d_row11_col8, #T_3dd4d_row12_col3, #T_3dd4d_row12_col8, #T_3dd4d_row12_col17, #T_3dd4d_row13_col3, #T_3dd4d_row14_col3, #T_3dd4d_row14_col8, #T_3dd4d_row15_col5, #T_3dd4d_row15_col7, #T_3dd4d_row16_col3, #T_3dd4d_row16_col8, #T_3dd4d_row16_col17, #T_3dd4d_row17_col5, #T_3dd4d_row19_col8, #T_3dd4d_row19_col17, #T_3dd4d_row20_col3, #T_3dd4d_row20_col5, #T_3dd4d_row20_col17, #T_3dd4d_row21_col17, #T_3dd4d_row22_col3 {
#   background-color: green;
#   color: white;
# }
# #T_3dd4d_row0_col14, #T_3dd4d_row0_col15, #T_3dd4d_row1_col14, #T_3dd4d_row1_col15, #T_3dd4d_row2_col14, #T_3dd4d_row2_col15, #T_3dd4d_row3_col15, #T_3dd4d_row4_col5, #T_3dd4d_row4_col6, #T_3dd4d_row4_col14, #T_3dd4d_row4_col15, #T_3dd4d_row5_col14, #T_3dd4d_row5_col15, #T_3dd4d_row6_col14, #T_3dd4d_row6_col15, #T_3dd4d_row7_col5, #T_3dd4d_row7_col6, #T_3dd4d_row7_col14, #T_3dd4d_row7_col15, #T_3dd4d_row8_col5, #T_3dd4d_row8_col6, #T
level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_3dd4d_level0_col1" class="col_heading level0 col1" >LowPrice</th>
#       <th id="T_3dd4d_level0_col2" class="col_heading level0 col2" >HighPrice</th>
#       <th id="T_3dd4d_level0_col3" class="col_heading level0 col3" >Growth</th>
#       <th id="T_3dd4d_level0_col4" class="col_heading level0 col4" >lastPrice</th>
#       <th id="T_3dd4d_level0_col5" class="col_heading level0 col5" >LowDiff</th>
#       <th id="T_3dd4d_level0_col6" class="col_heading level0 col6" >HighDiff</th>
#       <th id="T_3dd4d_level0_col7" class="col_heading level0 col7" >Quant Rating</th>
#       <th id="T_3dd4d_level0_col8" class="col_heading level0 col8" >DCF</th>
#       <th id="T_3dd4d_level0_col9" class="col_heading level0 col9" >Score</th>
#       <th id="T_3dd4d_level0_col10" class="col_heading level0 col10" >Sector</th>
#       <th id="T_3dd4d_level0_col11" class="col_heading level0 col11" >effective_epsy</th>
#       <th id="T_3dd4d_level0_col12" class="col_heading level0 col12" >Last Quarter Announce Date</th>
#       <th id="T_3dd4d_level0_col13" class="col_heading level0 col13" >EPS Revision Grade</th>
#       <th id="T_3dd4d_level0_col14" class="col_heading level0 col14" >PEG</th>
#       <th id="T_3dd4d_level0_col15" class="col_heading level0 col15" >PEG5</th>
#       <th id="T_3dd4d_level0_col16" class="col_heading level0 col16" >EMA_Note</th>
#       <th id="T_3dd4d_level0_col17" class="col_heading level0 col17" >INS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dd4d_level0_row0" class="row_heading level0 row0" >165</th>
#       <td id="T_3dd4d_row0_col0" class="data row0 col0" >UBER</td>
#       <td id="T_3dd4d_row0_col1" class="data row0 col1" >84.400000</td>
#       <td id="T_3dd4d_row0_col2" class="data row0 col2" >112.500000</td>
#       <td id="T_3dd4d_row0_col3" class="data row0 col3" >22.000000</td>
#       <td id="T_3dd4d_row0_col4" class="data row0 col4" >84.200000</td>
#       <td id="T_3dd4d_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_3dd4d_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_3dd4d_row0_col7" class="data row0 col7" >4.900000</td>
#       <td id="T_3dd4d_row0_col8" class="data row0 col8" >164.169020</td>
#       <td id="T_3dd4d_row0_col9" class="data row0 col9" >7.000000</td>
#       <td id="T_3dd4d_row0_col10" class="data row0 col10" >Industrials</td>
#       <td id="T_3dd4d_row0_col11" class="data row0 col11" >2025-12-31 00:00:00</td>
#       <td id="T_3dd4d_row0_col12" class="data row0 col12" >5/7/2025</td>
#       <td id="T_3dd4d_row0_col13" class="data row0 col13" >A-</td>
#       <td id="T_3dd4d_row0_col14" class="data row0 col14" >1.400000</td>
#       <td id="T_3dd4d_row0_col15" class="data row0 col15" >0.800000</td>
#       <td id="T_3dd4d_row0_col16" class="data row0 col16" >weekly up</td>
#       <td id="T_3dd4d_row0_col17" class="data row0 col17" >83.800000</td>
#     </tr>
#     <tr>
#       <th id="T_3dd4d_level0_row1" class="row_heading level0 row1" >140</th>
#       <td id="T_3dd4d_row1_col0" class="data row1 col0" >AMD</td>
#       <td id="T_3dd4d_row1_col1" class="data row1 col1" >120.100000</td>
#       <td id="T_3dd4d_row1_col2" class="data row1 col2" >160.200000</td>
#       <td id="T_3dd4d_row1_col3" class="data row1 col3" >41.900000</td>
#       <td id="T_3dd4d_row1_col4" class="data row1 col4" >110.700000</td>
#       <td id="T_3dd4d_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_3dd4d_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_3dd4d_row1_col7" class="data row1 col7" >3.100000</td>
#       <td id="T_3dd4d_row1_col8" class="data row1 col8" >145.099082</td>
#       <td id="T_3dd4d_row1_col9" class="data row1 col9" >6.000000</td>
#       <td id="T_3dd4d_row1_col10" class="data row1 col10" >Information Technology</td>
#       <td id="T_3dd4d_row1_col11" class="data row1 col11" >2025-12-31 00:00:00</td>
#       <td id="T_3dd4d_row1_col12" class="data row1 col12" >5/6/2025</td>
#       <td id="T_3dd4d_row1_col13" c

# %%
# Hardcoded list of symbols to filter by
selected_symbols = (['NVDA']+['META', 'AMZN','GOOGL']+                 
                   ['AAPL','TSLA','MSFT'])# Replace with your desired symbols

# Filter the DataFrame by the selected symbols
df_filtered = df_display[df_display['Symbol'].isin(selected_symbols)]

# Highlight styling for the filtered DataFrame
def highlight_row(row):
    styles = [''] * len(row)

    # Growth column styling
    if row['Growth'] < 0:
        styles[row.index.get_loc('Growth')] = 'background-color: red; color: white'
    elif 0 <= row['Growth'] < 8:
        styles[row.index.get_loc('Growth')] = 'background-color: yellow'
    else:
        styles[row.index.get_loc('Growth')] = 'background-color: green; color: white'

    # LowDiff column styling
    if row['LowDiff'] is True:
        styles[row.index.get_loc('LowDiff')] = 'background-color: green; color: white'
    elif isinstance(row['LowDiff'], float):
        styles[row.index.get_loc('LowDiff')] = 'background-color: green' if row['LowDiff'] < row['HighDiff'] else 'background-color: yellow'
    elif row['LowDiff'] is None:
        styles[row.index.get_loc('LowDiff')] = 'background-color: red; color: white'

    # HighDiff column styling
    if row['HighDiff'] is True:
        styles[row.index.get_loc('HighDiff')] = 'background-color: red; color: white'
    elif isinstance(row['HighDiff'], float):
        styles[row.index.get_loc('HighDiff')] = 'background-color: green'
     
    # PEG styling
    if row['PEG'] > 1.5:
        styles[row.index.get_loc('PEG')] = 'background-color: red; color: white'
    elif isinstance(row['PEG'], float):
        styles[row.index.get_loc('PEG')] = 'background-color: green'
     # PEG styling
    if row['PEG5'] > 1.5:
        styles[row.index.get_loc('PEG5')] = 'background-color: red; color: white'
    elif isinstance(row['PEG'], float):
        styles[row.index.get_loc('PEG5')] = 'background-color: green'
    # INS（机构持股比例）高亮
    try:
        ins = float(row['INS'])
        if ins >= 80:
            styles[row.index.get_loc('INS')] = 'background-color: green; color: white'
        elif ins < 70:
            styles[row.index.get_loc('INS')] = 'background-color: red; color: white'
        else:
            styles[row.index.get_loc('INS')] = 'background-color: yellow; color: black'
    except:
        pass  # 若 INS 无法转换为 float，则跳过
    # Quant Rating styling
    if row['Quant Rating'] > 4.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: green; color: white'
    elif 3.5 < row['Quant Rating'] <= 4.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: yellow'
    elif 2.5 <= row['Quant Rating'] <= 3.5:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: lightgray'
    else:
        styles[row.index.get_loc('Quant Rating')] = 'background-color: red; color: white'

    # DCF styling
    if row['DCF'] == 'N':
        styles[row.index.get_loc('DCF')] = 'background-color: lightgray'
    else:
        if row['lastPrice'] <= row['DCF'] * (1+row['Growth']/100):
            styles[row.index.get_loc('DCF')] = 'background-color: green; color: white'
        else:
            styles[row.index.get_loc('DCF')] = 'background-color: red; color: white'

    # Last Quarter Announce Date styling
    announce_date = pd.to_datetime(row['Last Quarter Announce Date'], errors='coerce')
    if pd.notnull(announce_date):
        # Range for ±7 days around Last Quarter Announce Date
        range_start_1 = announce_date - timedelta(days=8)
        range_end_1 = announce_date + timedelta(days=8)
        
        # Range for ±7 days around Last Quarter Announce Date + 90 days
        range_start_2 = announce_date + timedelta(days=90 - 8)
        range_end_2 = announce_date + timedelta(days=90 + 8)
        
        if range_start_1 <= today <= range_end_1:  # Within ±7 days of Last Quarter Announce Date
            styles[row.index.get_loc('Last Quarter Announce Date')] = 'background-color: green; color: white'
        elif range_start_2 <= today <= range_end_2:  # Within ±7 days of Last Quarter Announce Date + 90 days
            styles[row.index.get_loc('Last Quarter Announce Date')] = 'background-color: yellow'
    return styles

# Apply styling to the filtered DataFrame
styled_table = df_filtered.style.apply(highlight_row, axis=1)

# Display the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_f6ce3_row0_col3, #T_f6ce3_row1_col3, #T_f6ce3_row1_col7, #T_f6ce3_row2_col5, #T_f6ce3_row2_col17, #T_f6ce3_row3_col3, #T_f6ce3_row3_col17, #T_f6ce3_row4_col3, #T_f6ce3_row5_col3, #T_f6ce3_row6_col3 {
#   background-color: green;
#   color: white;
# }
# #T_f6ce3_row0_col5, #T_f6ce3_row0_col6, #T_f6ce3_row0_col14, #T_f6ce3_row1_col5, #T_f6ce3_row1_col6, #T_f6ce3_row1_col15, #T_f6ce3_row2_col15, #T_f6ce3_row3_col5, #T_f6ce3_row3_col6, #T_f6ce3_row3_col15, #T_f6ce3_row4_col6, #T_f6ce3_row6_col6 {
#   background-color: green;
# }
# #T_f6ce3_row0_col7, #T_f6ce3_row2_col7, #T_f6ce3_row3_col7, #T_f6ce3_row4_col7, #T_f6ce3_row5_col7, #T_f6ce3_row6_col7 {
#   background-color: lightgray;
# }
# #T_f6ce3_row0_col8, #T_f6ce3_row0_col15, #T_f6ce3_row1_col8, #T_f6ce3_row1_col14, #T_f6ce3_row2_col8, #T_f6ce3_row2_col14, #T_f6ce3_row3_col8, #T_f6ce3_row3_col14, #T_f6ce3_row4_col8, #T_f6ce3_row4_col14, #T_f6ce3_row4_col15, #T_f6ce3_row5_col5, #T_f6ce3_row5_col6, #T_f6ce3_row5_col8, #T_f6ce3_row5_col14, #T_f6ce3_row5_col15, #T_f6ce3_row5_col17, #T_f6ce3_row6_col8, #T_f6ce3_row6_col14, #T_f6ce3_row6_col15, #T_f6ce3_row6_col17 {
#   background-color: red;
#   color: white;
# }
# #T_f6ce3_row0_col12, #T_f6ce3_row2_col3, #T_f6ce3_row4_col5, #T_f6ce3_row6_col5 {
#   background-color: yellow;
# }
# #T_f6ce3_row0_col17, #T_f6ce3_row1_col17, #T_f6ce3_row4_col17 {
#   background-color: yellow;
#   color: black;
# }
# </style>
# <table id="T_f6ce3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6ce3_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_f6ce3_level0_col1" class="col_heading level0 col1" >LowPrice</th>
#       <th id="T_f6ce3_level0_col2" class="col_heading level0 col2" >HighPrice</th>
#       <th id="T_f6ce3_level0_col3" class="col_heading level0 col3" >Growth</th>
#       <th id="T_f6ce3_level0_col4" class="col_heading level0 col4" >lastPrice</th>
#       <th id="T_f6ce3_level0_col5" class="col_heading level0 col5" >LowDiff</th>
#       <th id="T_f6ce3_level0_col6" class="col_heading level0 col6" >HighDiff</th>
#       <th id="T_f6ce3_level0_col7" class="col_heading level0 col7" >Quant Rating</th>
#       <th id="T_f6ce3_level0_col8" class="col_heading level0 col8" >DCF</th>
#       <th id="T_f6ce3_level0_col9" class="col_heading level0 col9" >Score</th>
#       <th id="T_f6ce3_level0_col10" class="col_heading level0 col10" >Sector</th>
#       <th id="T_f6ce3_level0_col11" class="col_heading level0 col11" >effective_epsy</th>
#       <th id="T_f6ce3_level0_col12" class="col_heading level0 col12" >Last Quarter Announce Date</th>
#       <th id="T_f6ce3_level0_col13" class="col_heading level0 col13" >EPS Revision Grade</th>
#       <th id="T_f6ce3_level0_col14" class="col_heading level0 col14" >PEG</th>
#       <th id="T_f6ce3_level0_col15" class="col_heading level0 col15" >PEG5</th>
#       <th id="T_f6ce3_level0_col16" class="col_heading level0 col16" >EMA_Note</th>
#       <th id="T_f6ce3_level0_col17" class="col_heading level0 col17" >INS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6ce3_level0_row0" class="row_heading level0 row0" >142</th>
#       <td id="T_f6ce3_row0_col0" class="data row0 col0" >NVDA</td>
#       <td id="T_f6ce3_row0_col1" class="data row0 col1" >131.200000</td>
#       <td id="T_f6ce3_row0_col2" class="data row0 col2" >174.900000</td>
#       <td id="T_f6ce3_row0_col3" class="data row0 col3" >48.000000</td>
#       <td id="T_f6ce3_row0_col4" class="data row0 col4" >135.100000</td>
#       <td id="T_f6ce3_row0_col5" class="data row0 col5" >2.917931</td>
#       <td id="T_f6ce3_row0_col6" class="data row0 col6" >29.442759</td>
#       <td id="T_f6ce3_row0_col7" class="data row0 col7" >3.400000</td>
#       <td id="T_f6ce3_row0_col8" class="data row0 col8" >85.396372</td>
#       <td id="T_f6ce3_row0_col9" class="data row0 col9" >3.500000</td>
#       <td id="T_f6ce3_row0_col10" class="data row0 col10" >Information Technology</td>
#       <td id="T_f6ce3_row0_col11" class="data row0 col11" >2026-01-31 00:00:00</td>
#       <td id="T_f6ce3_row0_col12" class="data row0 col12" >2/26/2025</td>
#       <td id="T_f6ce3_row0_col13" class="data row0 col13" >B-</td>
#       <td id="T_f6ce3_row0_col14" class="data row0 col14" >1.000000</td>
#       <td id="T_f6ce3_row0_col15" class="data row0 col15" >1.700000</td>
#       <td id="T_f6ce3_row0_col16" class="data row0 col16" >weekly up</td>
#       <td id="T_f6ce3_row0_col17" class="data row0 col17" >70.600000</td>
#     </tr>
#     <tr>
#       <th id="T_f6ce3_level0_row1" class="row_heading level0 row1" >173</th>
#       <td id="T_f6ce3_row1_col0" class="data row1 col0" >AMZN</td>
#       <td id="T_f6ce3_row1_col1" class="data row1 col1" >185.800000</td>
#       <td id="T_f6ce3_row1_col2" class="data row1 col2" >247.700000</td>
#       <td id="T_f6ce3_row1_col3" class="data row1 col3" >17.200000</td>
#       <td id="T_f6ce3_row1_col4" class="data row1 col4" >205.000000</td>
