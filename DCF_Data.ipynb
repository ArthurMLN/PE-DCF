# %%
# %pip install yfinance
import sqlite3
import yfinance as yf
from datetime import datetime, timedelta
date_range=0
update_all= True # True is update all, 
# Function to parse date with multiple formats
def parse_date(date_str):
    """
    Parse a date string with multiple possible formats.
    """
    for fmt in ('%Y-%m-%d', '%m/%d/%Y', '%d/%m/%Y', '%Y-%m-%d %H:%M:%S'):
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            continue
    return None

# Function to fetch Yahoo Finance data
def fetch_yahoo_finance_data(symbol):
    try:
        stock = yf.Ticker(symbol)
        cashflow = stock.quarterly_cashflow
        balance_sheet = stock.balance_sheet
        shares_outstanding = stock.info.get('sharesOutstanding')
        current_stock_price = stock.info.get('currentPrice')  # Current stock price

        # Calculate TTM Free Cash Flow
        if "Free Cash Flow" in cashflow.index:
            ttm_free_cash_flow = cashflow.loc["Free Cash Flow"].iloc[:4].sum()
        else:
            ttm_free_cash_flow = None

        # Get the latest balance sheet data
        latest_date_balance = balance_sheet.columns[0]
        latest_balance_sheet = balance_sheet[latest_date_balance]
        cash_equivalents = latest_balance_sheet.get("Cash Cash Equivalents And Short Term Investments", 0)
        total_debt = latest_balance_sheet.get("Total Debt", 0)

        return {
            "Symbol": symbol,
            "Free Cash Flow": ttm_free_cash_flow or 0,
            "Cash Equivalents": float(cash_equivalents),
            "Total Debt": float(total_debt),
            "Shares Outstanding": shares_outstanding or 0,
            "Update Date": datetime.now().strftime('%Y-%m-%d'),  # Simplified human-readable date
        }
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return None

# Function to write or update data in the DCF_Data table
def write_or_update_database(db_path, data, er_date,symbol):
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Fetch existing record
        cursor.execute("SELECT Update_date FROM DCF_Data WHERE Symbol = ?", (data["Symbol"],))
        existing_entry = cursor.fetchone()

        # Parse ER_Date into a datetime object
        er_date_parsed = parse_date(er_date) if er_date else None

        update_needed = True
        if existing_entry:
            # Attempt to parse existing Update_date
            existing_update_date = parse_date(existing_entry[0])
            if existing_update_date and er_date_parsed:
                # Check if the update is needed
                if existing_update_date >= er_date_parsed - timedelta(days=date_range):
                    print (symbol,"Update in time, no action")
                    update_needed = False
                    update_needed = update_all   # update all   
        if update_needed:
            # Update or insert record
            if existing_entry:
                query = """
                UPDATE DCF_Data
                SET FCF = ?, Cash_Equivalents = ?, Total_debt = ?, Shares_outstanding = ?, Update_date = ?
                WHERE Symbol = ?
                """
                cursor.execute(query, (
                    data["Free Cash Flow"],
                    data["Cash Equivalents"],
                    data["Total Debt"],
                    data["Shares Outstanding"],
                    data["Update Date"],
                    data["Symbol"]
                ))
                print(f"Data for {data['Symbol']} updated successfully.")
            else:
                query = """
                INSERT INTO DCF_Data (Symbol, FCF, Cash_Equivalents, Total_debt, Shares_outstanding, Update_date)
                VALUES (?, ?, ?, ?, ?, ?)
                """
                cursor.execute(query, (
                    data["Symbol"],
                    data["Free Cash Flow"],
                    data["Cash Equivalents"],
                    data["Total Debt"],
                    data["Shares Outstanding"],
                    data["Update Date"]
                ))
                print(f"Data for {data['Symbol']} inserted successfully.")

        conn.commit()
    except sqlite3.Error as e:
        print(f"SQLite error: {e}")
    finally:
        conn.close()

# Function to fetch symbols and ER_Date from CValue table
def fetch_symbols_and_er_date(db_path):
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        query = """
        SELECT Symbol, ER_Date
        FROM CValue
        WHERE WACC IS NOT NULL AND Growth5Y IS NOT NULL;
        """
        cursor.execute(query)
        return cursor.fetchall()  # List of tuples (Symbol, ER_Date)
    except sqlite3.Error as e:
        print(f"SQLite error while fetching symbols and ER_Date: {e}")
        return []
    finally:
        conn.close()

# Main function
def main():
    db_path = "plan.db"  # Path to your SQLite database
    symbol_er_date_list = fetch_symbols_and_er_date(db_path)

    for symbol, er_date in symbol_er_date_list:
        data = fetch_yahoo_finance_data(symbol)
        if data:
            write_or_update_database(db_path, data, er_date,symbol)

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: yfinance in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (0.2.49)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.0.1)
# Requirement already satisfied: requests>=2.31 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rhino\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.
# MSFT Update in time, no action
# Data for MSFT updated successfully.
# AAPL Update in time, no action
# Data for AAPL updated successfully.
# PYPL Update in time, no action
# Data for PYPL updated successfully.
# CAT Update in time, no action
# Data for CAT updated successfully.
# CVX Update in time, no action
# Data for CVX updated successfully.
# V Update in time, no action
# Data for V updated successfully.
# META Update in time, no action
# Data for META updated successfully.
# HON Update in time, no action
# Data for HON updated successfully.
# UNH Update in time, no action
# Data for UNH updated successfully.
# GS Update in time, no action
# Data for GS updated successfully.
# HD Update in time, no action
# Data for HD updated successfully.
# WMT Update in time, no action
# Data for WMT updated successfully.
# GOOGL Update in time, no action
# Data for GOOGL updated successfully.
# NFLX Update in time, no action
# Data for NFLX updated successfully.
# TSLA Update in time, no action
# Data for TSLA updated successfully.
# FDX Update in time, no action
# Data for FDX updated successfully.
# MA Update in time, no action
# Data for MA updated successfully.
# ILMN Update in time, no action
# Data for ILMN updated successfully.
# TSM Update in time, no action
# Data for TSM updated successfully.
# CF Update in time, no action
# Data for CF updated successfully.
# TMO Update in time, no action
# Data for TMO updated successfully.
# JNJ Update in time, no action
# Data for JNJ updated successfully.
# XOM Update in time, no action
# Data for XOM updated successfully.
# BA Update in time, no action
# Data for BA updated successfully.
# PG Update in time, no action
# Data for PG updated successfully.
# DOW Update in time, no action
# Data for DOW updated successfully.
# VZ Update in time, no action
# Data for VZ updated successfully.
# DUK Update in time, no action
# Data for DUK updated successfully.
# ABBV Update in time, no action
# Data for ABBV updated successfully.
# PM Update in time, no action
# Data for PM updated successfully.
# BAC Update in time, no action
# Data for BAC updated successfully.
# MMM Update in time, no action
# Data for MMM updated successfully.
# MCD Update in time, no action
# Data for MCD updated successfully.
# AMGN Update in time, no action
# Data for AMGN updated successfully.
# JPM Update in time, no action
# Data for JPM updated successfully.
# BLK Update in time, no action
# Data for BLK updated successfully.
# ISRG Update in time, no action
# Data for ISRG updated successfully.
# GNRC Update in time, no action
# Data for GNRC updated successfully.
# MNST Update in time, no action
# Data for MNST updated successfully.
# MTH Update in time, no action
# Data for MTH updated successfully.
# ABT Update in time, no action
# Data for ABT updated successfully.
# IBM Update in time, no action
# Data for IBM updated successfully.
# TXN Update in time, no action
# Data for TXN updated successfully.
# NEE Update in time, no action
# Data for NEE updated successfully.
# AXP Update in time, no action
# Data for AXP updated successfully.
# LMT Update in time, no action
# Data for LMT updated successfully.
# GE Update in time, no action
# Data for GE updated successfully.
# INTC Update in time, no action
# Data for INTC updated successfully.
# T Update in time, no action
# Data for T updated successfully.
# KLAC Update in time, no action
# Data for KLAC updated successfully.
# MSCI Update in time, no action
# Data for MSCI updated successfully.
# NUE Update in time, no action
# Data for NUE updated successfully.
# LUV Update in time, no action
# Data for LUV updated successfully.
# ALK Update in time, no action
# Data for ALK updated successfully.
# X Update in time, no action
# Data for X updated successfully.
# CHTR Update in time, no action
# Data for CHTR updated successfully.
# CL Update in time, no action
# Data for CL updated successfully.
# ROK Update in time, no action
# Data for ROK updated successfully.
# DAL Update in time, no action
# Data for DAL updated successfully.
# UAL Update in time, no action
# Data for UAL updated successfully.
# AAL Update in time, no action
# Data for AAL updated successfully.
# WFC Update in time, no action
# Data for WFC updated successfully.
# C Update in time, no action
# Data for C updated successfully.
# SCHW Update in time, no action
# Data for SCHW updated successfully.
# PNC Update in time, no action
# Data for PNC updated successfully.
# BK Update in time, no action
# Data for BK updated successfully.
# MS Update in time, no action
# Data for MS updated successfully.
# USB Update in time, no action
# Data for USB updated successfully.
# LRCX Update in time, no action
# Data for LRCX updated successfully.
# FCX Update in time, no action
# Data for FCX updated successfully.
# KMB Update in time, no action
# Data for KMB updated successfully.
# MDLZ Update in time, no action
# Data for MDLZ updated successfully.
# MO Update in time, no action
# Data for MO updated successfully.
# NXPI Update in time, no action
# Data for NXPI updated successfully.
# UPS Update in time, no action
# Data for UPS updated successfully.
# SBUX Update in time, no action
# Data for SBUX updated successfully.
# GM Update in time, no action
# Data for GM updated successfully.
# EA Update in time, no action
# Data for EA updated successfully.
# PHM Update in time, no action
# Data for PHM updated successfully.
# DHI Update in time, no action
# Data for DHI updated successfully.
# QCOM Update in time, no action
# Data for QCOM updated successfully.
# TMUS Update in time, no action
# Data for TMUS updated successfully.
# LLY Update in time, no action
# Data for LLY updated successfully.
# MRK Update in time, no action
# Data for MRK updated successfully.
# EL Update in time, no action
# Data for EL updated successfully.
# F Update in time, no action
# Data for F updated successfully.
# PH Update in time, no action
# Data for PH updated successfully.
# BIIB Update in time, no action
# Data for BIIB updated successfully.
# CMI Update in time, no action
# Data for CMI updated successfully.
# ROP Update in time, no action
# Data for ROP updated successfully.
# LITE Update in time, no action
# Data for LITE updated successfully.
# REGN Update in time, no action
# Data for REGN updated successfully.
# APD Update in time, no action
# Data for APD updated successfully.
# CLX Update in time, no action
# Data for CLX updated successfully.
# ETN Update in time, no action
# Data for ETN updated successfully.
# UNP Update in time, no action
# Data for UNP updated successfully.
# PPG Update in time, no action
# Data for PPG updated successfully.
# TRV Update in time, no action
# Data for TRV updated successfully.
# WY Update in time, no action
# Data for WY updated successfully.
# TSN Update in time, no action
# Data for TSN updated successfully.
# SPG Update in time, no action
# Data for SPG updated successfully.
# DIS Update in time, no action
# Data for DIS updated successfully.
# CVS Update in time, no action
# Data for CVS updated successfully.
# PEP Update in time, no action
# Data for PEP updated successfully.
# MCO Update in time, no action
# Data for MCO updated successfully.
# DE Update in time, no action
# Data for DE updated successfully.
# AMAT Update in time, no action
# Data for AMAT updated successfully.
# VMC Update in time, no action
# Data for VMC updated successfully.
# LOW Update in time, no action
# Data for LOW updated successfully.
# BBY Update in time, no action
# Data for BBY updated successfully.
# STX Update in time, no action
# Data for STX updated successfully.
# WBA Update in time, no action
# Data for WBA updated successfully.
# SHOP Update in time, no action
# Data for SHOP updated successfully.
# OKTA Update in time, no action
# Data for OKTA updated successfully.
# NET Update in time, no action
# Data for NET updated successfully.
# ZS Update in time, no action
# Data for ZS updated successfully.
# CRWD Update in time, no action
# Data for CRWD updated successfully.
# NOW Update in time, no action
# Data for NOW updated successfully.
# TTD Update in time, no action
# Data for TTD updated successfully.
# DDOG Update in time, no action
# Data for DDOG updated successfully.
# HUBS Update in time, no action
# Data for HUBS updated successfully.
# TWLO Update in time, no action
# Data for TWLO updated successfully.
# CRM Update in time, no action
# Data for CRM updated successfully.
# SAP Update in time, no action
# Data for SAP updated successfully.
# FTNT Update in time, no action
# Data for FTNT updated successfully.
# ADSK Update in time, no action
# Data for ADSK updated successfully.
# PANW Update in time, no action
# Data for PANW updated successfully.
# DBX Update in time, no action
# Data for DBX updated successfully.
# ADBE Update in time, no action
# Data for ADBE updated successfully.
# ADP Update in time, no action
# Data for ADP updated successfully.
# ORCL Update in time, no action
# Data for ORCL updated successfully.
# INTU Update in time, no action
# Data for INTU updated successfully.
# CSCO Update in time, no action
# Data for CSCO updated successfully.
# ZM Update in time, no action
# Data for ZM updated successfully.
# MU Update in time, no action
# Data for MU updated successfully.
# TER Update in time, no action
# Data for TER updated successfully.
# QRVO Update in time, no action
# Data for QRVO updated successfully.
# MRVL Update in time, no action
# Data for MRVL updated successfully.
# AMKR Update in time, no action
# Data for AMKR updated successfully.
# POWI Update in time, no action
# Data for POWI updated successfully.
# AMD Update in time, no action
# Data for AMD updated successfully.
# ENTG Update in time, no action
# Data for ENTG updated successfully.
# NVDA Update in time, no action
# Data for NVDA updated successfully.
# SLAB Update in time, no action
# Data for SLAB updated successfully.
# LSCC Update in time, no action
# Data for LSCC updated successfully.
# ASML Update in time, no action
# Data for ASML updated successfully.
# AKAM Update in time, no action
# Data for AKAM updated successfully.
# UPST Update in time, no action
# Data for UPST updated successfully.
# PLTR Update in time, no action
# Data for PLTR updated successfully.
# ABNB Update in time, no action
# Data for ABNB updated successfully.
# U Update in time, no action
# Data for U updated successfully.
# MDT Update in time, no action
# Data for MDT updated successfully.
# KHC Update in time, no action
# Data for KHC updated successfully.
# MGA Update in time, no action
# Data for MGA updated successfully.
# D Update in time, no action
# Data for D updated successfully.
# YUM Update in time, no action
# Data for YUM updated successfully.
# ALB Update in time, no action
# Data for ALB updated successfully.
# MOS Update in time, no action
# Data for MOS updated successfully.
# ETSY Update in time, no action
# Data for ETSY updated successfully.
# EIX Update in time, no action
# Data for EIX updated successfully.
# O Update in time, no action
# Data for O updated successfully.
# VRTX Update in time, no action
# Data for VRTX updated successfully.
# PFE Update in time, no action
# Data for PFE updated successfully.
# EXPE Update in time, no action
# Data for EXPE updated successfully.
# BKNG Update in time, no action
# Data for BKNG updated successfully.
# UBER Update in time, no action
# Data for UBER updated successfully.
# MAR Update in time, no action
# Data for MAR updated successfully.
# RCL Update in time, no action
# Data for RCL updated successfully.
# SQ Update in time, no action
# Data for SQ updated successfully.
# EBAY Update in time, no action
# Data for EBAY updated successfully.
# MPW Update in time, no action
# Data for MPW updated successfully.
# AMT Update in time, no action
# Data for AMT updated successfully.
# HAS Update in time, no action
# Data for HAS updated successfully.
# AMZN Update in time, no action
# Data for AMZN updated successfully.
# ENPH Update in time, no action
# Data for ENPH updated successfully.
# CDNS Update in time, no action
# Data for CDNS updated successfully.
# CMG Update in time, no action
# Data for CMG updated successfully.
# KO Update in time, no action
# Data for KO updated successfully.
# RTX Update in time, no action
# Data for RTX updated successfully.
# SHW Update in time, no action
# Data for SHW updated successfully.
# ALGN Update in time, no action
# Data for ALGN updated successfully.
# DXCM Update in time, no action
# Data for DXCM updated successfully.
# CME Update in time, no action
# Data for CME updated successfully.
# SPGI Update in time, no action
# Data for SPGI updated successfully.
# WM Update in time, no action
# Data for WM updated successfully.
# LIN Update in time, no action
# Data for LIN updated successfully.
# NOC Update in time, no action
# Data for NOC updated successfully.
# LYFT Update in time, no action
# Data for LYFT updated successfully.
# GOOS Update in time, no action
# Data for GOOS updated successfully.
# SE Update in time, no action
# Data for SE updated successfully.
# BIDU Update in time, no action
# Data for BIDU updated successfully.
# TJX Update in time, no action
# Data for TJX updated successfully.
# TGT Update in time, no action
# Data for TGT updated successfully.
# KKR Update in time, no action
# Data for KKR updated successfully.
# A Update in time, no action
# Data for A updated successfully.
# ON Update in time, no action
# Data for ON updated successfully.
# SNAP Update in time, no action
# Data for SNAP updated successfully.
# DHR Update in time, no action
# Data for DHR updated successfully.
# BTU Update in time, no action
# Data for BTU updated successfully.
# CENX Update in time, no action
# Data for CENX updated successfully.
# AA Update in time, no action
# Data for AA updated successfully.
# SCCO Update in time, no action
# Data for SCCO updated successfully.
# TGB Update in time, no action
# Data for TGB updated successfully.
# BKR Update in time, no action
# Data for BKR updated successfully.
# SLB Update in time, no action
# Data for SLB updated successfully.
# ZIM Update in time, no action
# Data for ZIM updated successfully.
# NEM Update in time, no action
# Data for NEM updated successfully.
# IAG Update in time, no action
# Data for IAG updated successfully.
# MCHP Update in time, no action
# Data for MCHP updated successfully.
# PBI Update in time, no action
# Data for PBI updated successfully.
# KGC Update in time, no action
# Data for KGC updated successfully.
# VIRT Update in time, no action
# Data for VIRT updated successfully.
# ALL Update in time, no action
# Data for ALL updated successfully.
# MFC Update in time, no action
# Data for MFC updated successfully.
# VEON Update in time, no action
# Data for VEON updated successfully.
# EGO Update in time, no action
# Data for EGO updated successfully.
# NGD Update in time, no action
# Data for NGD updated successfully.
# PAAS Update in time, no action
# Data for PAAS updated successfully.
# SVM Update in time, no action
# Data for SVM updated successfully.
# GLDD Update in time, no action
# Data for GLDD updated successfully.
# ET Update in time, no action
# Data for ET updated successfully.
# MPLX Update in time, no action
# Data for MPLX updated successfully.
# TRGP Update in time, no action
# Data for TRGP updated successfully.
# WES Update in time, no action
# Data for WES updated successfully.
# EPD Update in time, no action
# Data for EPD updated successfully.
# KMI Update in time, no action
# Data for KMI updated successfully.
# APO Update in time, no action
# Data for APO updated successfully.
# WBS Update in time, no action
# Data for WBS updated successfully.
# EWBC Update in time, no action
# Data for EWBC updated successfully.
# SO Update in time, no action
# Data for SO updated successfully.
# SKYW Update in time, no action
# Data for SKYW updated successfully.
# MCY Update in time, no action
# Data for MCY updated successfully.
# VIST Update in time, no action
# Data for VIST updated successfully.
# TS Update in time, no action
# Data for TS updated successfully.
# JD Update in time, no action
# Data for JD updated successfully.
# BABA Update in time, no action
# Data for BABA updated successfully.
# SWKS Update in time, no action
# Data for SWKS updated successfully.
# KRC Update in time, no action
# Data for KRC updated successfully.
# OXY Update in time, no action
# Data for OXY updated successfully.
# PPC Update in time, no action
# Data for PPC updated successfully.
# SMG Update in time, no action
# Data for SMG updated successfully.
# CTVA Update in time, no action
# Data for CTVA updated successfully.
# ADM Update in time, no action
# Data for ADM updated successfully.
# BG Update in time, no action
# Data for BG updated successfully.
# DAR Update in time, no action
# Data for DAR updated successfully.
# INGR Update in time, no action
# Data for INGR updated successfully.
# CAG Update in time, no action
# Data for CAG updated successfully.
# KLG Update in time, no action
# Data for KLG updated successfully.
# KR Update in time, no action
# Data for KR updated successfully.
# ALEX Update in time, no action
# Data for ALEX updated successfully.
# LEN Update in time, no action
# Data for LEN updated successfully.
# TOL Update in time, no action
# Data for TOL updated successfully.
# TTWO Update in time, no action
# Data for TTWO updated successfully.
# HSY Update in time, no action
# Data for HSY updated successfully.
# CPAY Update in time, no action
# Data for CPAY updated successfully.
# ARM Update in time, no action
# Data for ARM updated successfully.
# ANET Update in time, no action
# Data for ANET updated successfully.
# PINS Update in time, no action
# Data for PINS updated successfully.
# MELI Update in time, no action
# Data for MELI updated successfully.
# MTCH Update in time, no action
# Data for MTCH updated successfully.
# ZTS Update in time, no action
# Data for ZTS updated successfully.
# TRIP Update in time, no action
# Data for TRIP updated successfully.
# NCLH Update in time, no action
# Data for NCLH updated successfully.
# SU Update in time, no action
# Data for SU updated successfully.
# NKE Update in time, no action
# Data for NKE updated successfully.
# SHEL Update in time, no action
# Data for SHEL updated successfully.
# IMO Update in time, no action
# Data for IMO updated successfully.
# PR Update in time, no action
# Data for PR updated successfully.
# CTRA Update in time, no action
# Data for CTRA updated successfully.
# NRG Update in time, no action
# Data for NRG updated successfully.
# COF Update in time, no action
# Data for COF updated successfully.
# DFS Update in time, no action
# Data for DFS updated successfully.
# COST Update in time, no action
# Data for COST updated successfully.
# LULU Update in time, no action
# Data for LULU updated successfully.
# SNOW Update in time, no action
# Data for SNOW updated successfully.
# ROST Update in time, no action
# Data for ROST updated successfully.
# PDD Update in time, no action
# Data for PDD updated successfully.
# XPEV Update in time, no action
# Data for XPEV updated successfully.
# NIO Update in time, no action
# Data for NIO updated successfully.
# COIN Update in time, no action
# Data for COIN updated successfully.
# CB Update in time, no action
# Data for CB updated successfully.
# ITW Update in time, no action
# Data for ITW updated successfully.
# CBOE Update in time, no action
# Data for CBOE updated successfully.
# DASH Update in time, no action
# Data for DASH updated successfully.
# MPWR Update in time, no action
# Data for MPWR updated successfully.
# ENB Update in time, no action
# Data for ENB updated successfully.
# FSLR Update in time, no action
# Data for FSLR updated successfully.
# LI Update in time, no action
# Data for LI updated successfully.
# LVS Update in time, no action
# Data for LVS updated successfully.
# AN Update in time, no action
# Data for AN updated successfully.
# NVO Update in time, no action
# Data for NVO updated successfully.
# SNPS Update in time, no action
# Data for SNPS updated successfully.
# CCI Update in time, no action
# Data for CCI updated successfully.
# STT Update in time, no action
# Data for STT updated successfully.
# CI Update in time, no action
# Data for CI updated successfully.
# CFLT Update in time, no action
# Data for CFLT updated successfully.
# TEAM Update in time, no action
# Data for TEAM updated successfully.
# FTK Update in time, no action
# Data for FTK updated successfully.
# SXT Update in time, no action
# Data for SXT updated successfully.
# IDXX Update in time, no action
# Data for IDXX updated successfully.
# AVGO Update in time, no action
# Data for AVGO updated successfully.
# FMS Update in time, no action
# Data for FMS updated successfully.
# DLTR Update in time, no action
# Data for DLTR updated successfully.
# MDB Update in time, no action
# Data for MDB updated successfully.
# EXEL Update in time, no action
# Data for EXEL updated successfully.
# DELL Update in time, no action
# Data for DELL updated successfully.
# BX Update in time, no action
# Data for BX updated successfully.
# FAST Update in time, no action
# Data for FAST updated successfully.
# DPZ Update in time, no action
# Data for DPZ updated successfully.
# ACN Update in time, no action
# Data for ACN updated successfully.
# DG Update in time, no action
# Data for DG updated successfully.
# ULTA Update in time, no action
# Data for ULTA updated successfully.
# RH Update in time, no action
# Data for RH updated successfully.
# DOCU Update in time, no action
# Data for DOCU updated successfully.
# CHWY Update in time, no action
# Data for CHWY updated successfully.
# KMX Update in time, no action
# Data for KMX updated successfully.
# M Update in time, no action
# Data for M updated successfully.
# ADI Update in time, no action
# Data for ADI updated successfully.
# CSX Update in time, no action
# Data for CSX updated successfully.
# EQIX Update in time, no action
# Data for EQIX updated successfully.
# CNI Update in time, no action
# Data for CNI updated successfully.
# GILD Update in time, no action
# Data for GILD updated successfully.
# DD Update in time, no action
# Data for DD updated successfully.
# CRH Update in time, no action
# Data for CRH updated successfully.
# Data for ECL updated successfully.

# %%
from datetime import date, datetime, timedelta
import sqlite3
import pandas as pd
import yfinance as yf
#成熟企业：WACC 通常在 8%-12%。
#高风险行业（如科技、创业公司）：WACC 较高（12%-20%）。
#稳定行业（如公用事业、消费品）：WACC 较低（6%-8%）。
#Growth Rate 对于轻资产行业可以用EPS 3-5 年增速代替。重资产行业用Free Cash Flow Per Share Growth Rate (FWD) 的五年平均值代替
# 最优解是 Growth 里的EPS FWD Long Term Growth (3-5Y CAGR) 其次是Free Cash Flow Per Share Growth Rate (FWD) 最次是Revenu5Y 但是要求很高的WACC
# WACC或者折现率也可以理解为你对于回报的期望值比如说不能低于十年期国债的收益率多2%作为风险回报,  或者不能低于同行业的平均值
# Constants

GDP = 0.03  # Permanent growth rate (long-term GDP growth)
current_date = date.today().strftime('%Y-%m-%d')

# Set the threshold for DCF update in days (0 = update all)
days_threshold = 5  # Example: Update if DCFDate is older than 10 days

# Database path
db_path = "plan.db"

# Query to fetch data
query = """
SELECT Symbol, WACC, Growth5Y,Growth10Y,DCFDate
FROM CValue
WHERE WACC IS NOT NULL AND Growth5Y IS NOT NULL;
"""

# Function to fetch Yahoo Finance data
import sqlite3

# Function to fetch data from the database
def fetch_data_from_database(db_path, symbol):
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Query to fetch data for the given symbol
        query = """
        SELECT FCF, Cash_Equivalents, Total_debt, Shares_outstanding, Update_date, Manullly
        FROM DCF_Data
        WHERE Symbol = ?;
        """
        cursor.execute(query, (symbol,))
        result = cursor.fetchone()

        if result:
            # Map the result to a dictionary
            return {
                "Free Cash Flow": result[0],
                "Cash Equivalents": result[1],
                "Total Debt": result[2],
                "Shares Outstanding": result[3],
                "Update Date": result[4],
                "Manually": result[5],
            }
        else:
            print(f"No data found for symbol: {symbol}")
            return None
    except sqlite3.Error as e:
        print(f"SQLite error while fetching data for {symbol}: {e}")
        return None
    finally:
        conn.close()


# Main program
try:
    with sqlite3.connect(db_path) as conn:
        # Fetch data from the database
        df_wacc_growth = pd.read_sql_query(query, conn)

        # Initialize results list
        results = []

        # Iterate over each stock in the database
        for i, row in df_wacc_growth.iterrows():
            symbol = row['Symbol']
            print(f"\nProcessing {symbol}...")  # Log current Symbol
            wacc = row['WACC'] / 100  # Convert to decimal
            growth_rate = row['Growth5Y'] / 100  # Convert to decimal
            growth_rate_10 = row['Growth10Y'] / 100 if isinstance(row['Growth10Y'], (int, float)) else growth_rate * 0.8 # 没有二段数据就用80%
            dcf_date = row.get('DCFDate')  # Read DCFDate

            # Skip if Growth Rate is negative
            if growth_rate < 0:
                print(f"Skipping {symbol}: Growth Rate is negative.")
                continue

            # Check if DCF needs to be updated
            if dcf_date:
                try:
                    dcf_date = datetime.strptime(dcf_date, '%Y-%m-%d')
                    days_since_update = (datetime.now() - dcf_date).days
                    if days_threshold > 0 and days_since_update <= days_threshold:
                        print(f"Skipping {symbol}: Last updated {days_since_update} days ago.")
                        continue
                except ValueError:
                    print(f"Invalid DCFDate for {symbol}, recalculating.")
            else:
                print(f"Missing DCFDate for {symbol}, recalculating.")

            # Fetch Yahoo Finance data and process normally
            finance_data = fetch_data_from_database(db_path, symbol)
            
            if not finance_data:
                print(f"Error fetching data for {symbol}, skipping.")
                continue

            free_cash_flow = finance_data["Free Cash Flow"]
            cash_equivalents = finance_data["Cash Equivalents"]
            total_debt = finance_data["Total Debt"]
            shares_outstanding = finance_data["Shares Outstanding"]
            

            # Skip if any critical data is missing
            if None in (free_cash_flow, cash_equivalents, total_debt, shares_outstanding):
                print(f"Skipping {symbol}: Missing financial data.")
                continue

            # Print intermediate data for debugging
            
            print(f"  TTM Free Cash Flow: {free_cash_flow}")
            print(f"  Cash Equivalents: {cash_equivalents}")
            print(f"  Total Debt: {total_debt}")
            print(f"  Shares Outstanding: {shares_outstanding}")
            

            # Calculate cash flows for the next 10 years
            future_cash_flows = []
            current_cash_flow = free_cash_flow
            for year in range(1, 6):  # First 5 years
                current_cash_flow *= (1 + growth_rate)
                future_cash_flows.append(current_cash_flow)
            for year in range(6, 11):  # Next 5 years with reduced growth
                current_cash_flow *= (1 + growth_rate_10)
                future_cash_flows.append(current_cash_flow)

            # Print projected future cash flows for debugging
            print(f"  Projected Future Cash Flows (Years 1-10): {future_cash_flows}")

            # Calculate terminal value
            terminal_value = future_cash_flows[-1] * (1 + GDP) / (wacc - GDP)
            print(f"  Terminal Value (TV): {terminal_value}")  # Log terminal value
            future_cash_flows[-1] += terminal_value

            # Calculate discounted cash flows
            discounted_cash_flows = [
                cash_flow / (1 + wacc) ** year for year, cash_flow in enumerate(future_cash_flows, start=1)
            ]
            enterprise_value = sum(discounted_cash_flows)

            # Print enterprise value for debugging
            print(f"  Enterprise Value (EV): {enterprise_value}")

            # Calculate equity value and DCF price
            equity_value = enterprise_value + cash_equivalents - total_debt
            try:
                dcf_price = equity_value / shares_outstanding
            except:
                dcf_price = 0
            # Append result
            results.append({
                "Symbol": symbol,
                "WACC": wacc * 100,
                "Growth Rate (%)": growth_rate * 100,
                "DCF Price": dcf_price,                
            })

            # Log next Symbol (if exists)
            if i + 1 < len(df_wacc_growth):
                next_symbol = df_wacc_growth.iloc[i + 1]['Symbol']
                print(f"Next symbol to process: {next_symbol}")
            else:
                print("No more symbols to process.")

        # Write DCF results back to the database
        cursor = conn.cursor()
        cursor.execute("PRAGMA table_info(CValue);")
        columns = [col[1] for col in cursor.fetchall()]

        if "DCF" not in columns:
            cursor.execute("ALTER TABLE CValue ADD COLUMN DCF REAL;")
        if "DCFDate" not in columns:
            cursor.execute("ALTER TABLE CValue ADD COLUMN DCFDate TEXT;")

        for result in results:
            cursor.execute(
                "UPDATE CValue SET DCF = ?, DCFDate = ? WHERE Symbol = ?;",
                (result["DCF Price"], current_date, result["Symbol"])
            )
            print (result)
        #conn.commit()

        print("DCF values successfully written back to the database.")

except Exception as e:
    print("Error:", str(e))
# Out:
# Processing MSFT...
# Skipping MSFT: Last updated 0 days ago.
#
# Processing AAPL...
# Skipping AAPL: Last updated 0 days ago.
#
# Processing PYPL...
# Skipping PYPL: Last updated 0 days ago.
#
# Processing CAT...
# Skipping CAT: Last updated 0 days ago.
#
# Processing CVX...
# Skipping CVX: Last updated 0 days ago.
#
# Processing V...
# Skipping V: Last updated 0 days ago.
#
# Processing META...
# Skipping META: Last updated 0 days ago.
#
# Processing HON...
# Skipping HON: Last updated 0 days ago.
#
# Processing UNH...
# Skipping UNH: Last updated 0 days ago.
#
# Processing GS...
# Skipping GS: Last updated 0 days ago.
#
# Processing HD...
# Skipping HD: Last updated 0 days ago.
#
# Processing WMT...
# Skipping WMT: Last updated 0 days ago.
#
# Processing GOOGL...
# Skipping GOOGL: Last updated 0 days ago.
#
# Processing NFLX...
# Skipping NFLX: Last updated 0 days ago.
#
# Processing TSLA...
# Skipping TSLA: Last updated 0 days ago.
#
# Processing FDX...
# Skipping FDX: Last updated 0 days ago.
#
# Processing MA...
# Skipping MA: Last updated 0 days ago.
#
# Processing ILMN...
# Skipping ILMN: Last updated 0 days ago.
#
# Processing TSM...
# Skipping TSM: Last updated 0 days ago.
#
# Processing CF...
# Skipping CF: Last updated 0 days ago.
#
# Processing TMO...
# Skipping TMO: Last updated 0 days ago.
#
# Processing JNJ...
# Skipping JNJ: Last updated 0 days ago.
#
# Processing XOM...
# Skipping XOM: Last updated 0 days ago.
#
# Processing BA...
# Skipping BA: Last updated 0 days ago.
#
# Processing PG...
# Skipping PG: Last updated 0 days ago.
#
# Processing DOW...
# Skipping DOW: Last updated 0 days ago.
#
# Processing VZ...
# Skipping VZ: Last updated 0 days ago.
#
# Processing DUK...
# Skipping DUK: Last updated 0 days ago.
#
# Processing ABBV...
# Skipping ABBV: Last updated 0 days ago.
#
# Processing PM...
# Skipping PM: Last updated 0 days ago.
#
# Processing BAC...
# Skipping BAC: Last updated 0 days ago.
#
# Processing MMM...
# Skipping MMM: Last updated 0 days ago.
#
# Processing MCD...
# Skipping MCD: Last updated 0 days ago.
#
# Processing AMGN...
# Skipping AMGN: Last updated 0 days ago.
#
# Processing JPM...
# Skipping JPM: Last updated 0 days ago.
#
# Processing BLK...
# Skipping BLK: Last updated 0 days ago.
#
# Processing ISRG...
# Skipping ISRG: Missing financial data.
#
# Processing GNRC...
# Skipping GNRC: Last updated 0 days ago.
#
# Processing MNST...
# Skipping MNST: Last updated 0 days ago.
#
# Processing MTH...
# Skipping MTH: Last updated 0 days ago.
#
# Processing ABT...
# Skipping ABT: Last updated 0 days ago.
#
# Processing IBM...
# Skipping IBM: Last updated 0 days ago.
#
# Processing TXN...
# Skipping TXN: Last updated 0 days ago.
#
# Processing NEE...
# Skipping NEE: Last updated 0 days ago.
#
# Processing AXP...
# Skipping AXP: Last updated 0 days ago.
#
# Processing LMT...
# Skipping LMT: Last updated 0 days ago.
#
# Processing GE...
# Skipping GE: Last updated 0 days ago.
#
# Processing INTC...
# Skipping INTC: Last updated 0 days ago.
#
# Processing T...
# Skipping T: Last updated 0 days ago.
#
# Processing KLAC...
# Skipping KLAC: Last updated 0 days ago.
#
# Processing MSCI...
# Skipping MSCI: Last updated 0 days ago.
#
# Processing NUE...
# Skipping NUE: Last updated 0 days ago.
#
# Processing LUV...
# Skipping LUV: Last updated 0 days ago.
#
# Processing ALK...
# Skipping ALK: Growth Rate is negative.
#
# Processing X...
# Skipping X: Growth Rate is negative.
#
# Processing CHTR...
# Skipping CHTR: Last updated 0 days ago.
#
# Processing CL...
# Skipping CL: Last updated 0 days ago.
#
# Processing ROK...
# Skipping ROK: Last updated 0 days ago.
#
# Processing DAL...
# Skipping DAL: Last updated 0 days ago.
#
# Processing UAL...
# Skipping UAL: Last updated 0 days ago.
#
# Processing AAL...
# Skipping AAL: Growth Rate is negative.
#
# Processing WFC...
# Skipping WFC: Last updated 0 days ago.
#
# Processing C...
# Skipping C: Last updated 0 days ago.
#
# Processing SCHW...
# Skipping SCHW: Last updated 0 days ago.
#
# Processing PNC...
# Skipping PNC: Last updated 0 days ago.
#
# Processing BK...
# Skipping BK: Last updated 0 days ago.
#
# Processing MS...
# Skipping MS: Last updated 0 days ago.
#
# Processing USB...
# Skipping USB: Last updated 0 days ago.
#
# Processing LRCX...
# Skipping LRCX: Last updated 0 days ago.
#
# Processing FCX...
# Skipping FCX: Last updated 0 days ago.
#
# Processing KMB...
# Skipping KMB: Last updated 0 days ago.
#
# Processing MDLZ...
# Skipping MDLZ: Last updated 0 days ago.
#
# Processing MO...
# Skipping MO: Last updated 0 days ago.
#
# Processing NXPI...
# Skipping NXPI: Last updated 0 days ago.
#
# Processing UPS...
# Skipping UPS: Last updated 0 days ago.
#
# Processing SBUX...
# Skipping SBUX: Last updated 0 days ago.
#
# Processing GM...
# Skipping GM: Last updated 0 days ago.
#
# Processing EA...
# Skipping EA: Last updated 0 days ago.
#
# Processing PHM...
# Skipping PHM: Last updated 0 days ago.
#
# Processing DHI...
# Skipping DHI: Last updated 0 days ago.
#
# Processing QCOM...
# Skipping QCOM: Last updated 0 days ago.
#
# Processing TMUS...
# Skipping TMUS: Last updated 0 days ago.
#
# Processing LLY...
# Skipping LLY: Last updated 0 days ago.
#
# Processing MRK...
# Skipping MRK: Last updated 0 days ago.
#
# Processing EL...
# Skipping EL: Last updated 0 days ago.
#
# Processing F...
# Skipping F: Last updated 0 days ago.
#
# Processing PH...
# Skipping PH: Last updated 0 days ago.
#
# Processing BIIB...
# Skipping BIIB: Last updated 0 days ago.
#
# Processing CMI...
# Skipping CMI: Last updated 0 days ago.
#
# Processing ROP...
# Skipping ROP: Last updated 0 days ago.
#
# Processing LITE...
# Skipping LITE: Last updated 0 days ago.
#
# Processing REGN...
# Skipping REGN: Last updated 0 days ago.
#
# Processing APD...
# Skipping APD: Last updated 0 days ago.
#
# Processing CLX...
# Skipping CLX: Last updated 0 days ago.
#
# Processing ETN...
# Skipping ETN: Last updated 0 days ago.
#
# Processing UNP...
# Skipping UNP: Last updated 0 days ago.
#
# Processing PPG...
# Skipping PPG: Last updated 0 days ago.
#
# Processing TRV...
# Skipping TRV: Last updated 0 days ago.
#
# Processing WY...
# Skipping WY: Growth Rate is negative.
#
# Processing TSN...
# Skipping TSN: Last updated 0 days ago.
#
# Processing SPG...
# Skipping SPG: Last updated 0 days ago.
#
# Processing DIS...
# Skipping DIS: Last updated 0 days ago.
#
# Processing CVS...
# Skipping CVS: Last updated 0 days ago.
#
# Processing PEP...
# Skipping PEP: Last updated 0 days ago.
#
# Processing MCO...
# Skipping MCO: Missing financial data.
#
# Processing DE...
# Skipping DE: Last updated 0 days ago.
#
# Processing AMAT...
# Skipping AMAT: Last updated 0 days ago.
#
# Processing VMC...
# Skipping VMC: Last updated 0 days ago.
#
# Processing LOW...
# Skipping LOW: Last updated 0 days ago.
#
# Processing BBY...
# Skipping BBY: Last updated 0 days ago.
#
# Processing STX...
# Skipping STX: Last updated 0 days ago.
#
# Processing WBA...
# Skipping WBA: Growth Rate is negative.
#
# Processing SHOP...
# Skipping SHOP: Last updated 0 days ago.
#
# Processing OKTA...
# Skipping OKTA: Last updated 0 days ago.
#
# Processing NET...
# Skipping NET: Last updated 0 days ago.
#
# Processing ZS...
# Skipping ZS: Last updated 0 days ago.
#
# Processing CRWD...
# Skipping CRWD: Last updated 0 days ago.
#
# Processing NOW...
# Skipping NOW: Last updated 0 days ago.
#
# Processing TTD...
# Skipping TTD: Last updated 0 days ago.
#
# Processing DDOG...
# Skipping DDOG: Last updated 0 days ago.
#
# Processing HUBS...
# Skipping HUBS: Last updated 0 days ago.
#
# Processing TWLO...
# Skipping TWLO: Last updated 0 days ago.
#
# Processing CRM...
# Skipping CRM: Last updated 0 days ago.
#
# Processing SAP...
# Skipping SAP: Last updated 0 days ago.
#
# Processing FTNT...
# Skipping FTNT: Last updated 0 days ago.
#
# Processing ADSK...
# Skipping ADSK: Last updated 0 days ago.
#
# Processing PANW...
# Skipping PANW: Last updated 0 days ago.
#
# Processing DBX...
# Skipping DBX: Last updated 0 days ago.
#
# Processing ADBE...
# Skipping ADBE: Last updated 0 days ago.
#
# Processing ADP...
# Skipping ADP: Last updated 0 days ago.
#
# Processing ORCL...
# Skipping ORCL: Last updated 0 days ago.
#
# Processing INTU...
# Skipping INTU: Last updated 0 days ago.
#
# Processing CSCO...
# Skipping CSCO: Last updated 0 days ago.
#
# Processing ZM...
# Skipping ZM: Last updated 0 days ago.
#
# Processing MU...
# Skipping MU: Last updated 0 days ago.
#
# Processing TER...
# Skipping TER: Last updated 0 days ago.
#
# Processing QRVO...
# Skipping QRVO: Last updated 0 days ago.
#
# Processing MRVL...
# Skipping MRVL: Last updated 0 days ago.
#
# Processing AMKR...
# Skipping AMKR: Last updated 0 days ago.
#
# Processing POWI...
# Skipping POWI: Last updated 0 days ago.
#
# Processing AMD...
# Skipping AMD: Last updated 0 days ago.
#
# Processing ENTG...
# Skipping ENTG: Last updated 0 days ago.
#
# Processing NVDA...
# Skipping NVDA: Last updated 0 days ago.
#
# Processing SLAB...
# Skipping SLAB: Last updated 0 days ago.
#
# Processing LSCC...
# Skipping LSCC: Last updated 0 days ago.
#
# Processing ASML...
# Skipping ASML: Last updated 0 days ago.
#
# Processing AKAM...
# Skipping AKAM: Last updated 0 days ago.
#
# Processing UPST...
# Skipping UPST: Last updated 0 days ago.
#
# Processing PLTR...
# Skipping PLTR: Last updated 0 days ago.
#
# Processing ABNB...
# Skipping ABNB: Last updated 0 days ago.
#
# Processing U...
# Skipping U: Growth Rate is negative.
#
# Processing MDT...
# Skipping MDT: Last updated 0 days ago.
#
# Processing KHC...
# Skipping KHC: Last updated 0 days ago.
#
# Processing MGA...
# Skipping MGA: Last updated 0 days ago.
#
# Processing D...
# Skipping D: Last updated 0 days ago.
#
# Processing YUM...
# Skipping YUM: Last updated 0 days ago.
#
# Processing ALB...
# Skipping ALB: Last updated 0 days ago.
#
# Processing MOS...
# Skipping MOS: Growth Rate is negative.
#
# Processing ETSY...
# Skipping ETSY: Last updated 0 days ago.
#
# Processing EIX...
# Skipping EIX: Last updated 0 days ago.
#
# Processing O...
# Skipping O: Last updated 0 days ago.
#
# Processing VRTX...
# Skipping VRTX: Last updated 0 days ago.
#
# Processing PFE...
# Skipping PFE: Last updated 0 days ago.
#
# Processing EXPE...
# Skipping EXPE: Last updated 0 days ago.
#
# Processing BKNG...
# Skipping BKNG: Last updated 0 days ago.
#
# Processing UBER...
# Skipping UBER: Last updated 0 days ago.
#
# Processing MAR...
# Skipping MAR: Last updated 0 days ago.
#
# Processing RCL...
# Skipping RCL: Last updated 0 days ago.
#
# Processing SQ...
# Skipping SQ: Last updated 0 days ago.
#
# Processing EBAY...
# Skipping EBAY: Last updated 0 days ago.
#
# Processing MPW...
# Skipping MPW: Growth Rate is negative.
#
# Processing AMT...
# Skipping AMT: Last updated 0 days ago.
#
# Processing HAS...
# Skipping HAS: Last updated 0 days ago.
#
# Processing AMZN...
# Skipping AMZN: Last updated 0 days ago.
#
# Processing ENPH...
# Skipping ENPH: Last updated 0 days ago.
#
# Processing CDNS...
# Skipping CDNS: Last updated 0 days ago.
#
# Processing CMG...
# Skipping CMG: Last updated 0 days ago.
#
# Processing KO...
# Skipping KO: Last updated 0 days ago.
#
# Processing RTX...
# Skipping RTX: Last updated 0 days ago.
#
# Processing SHW...
# Skipping SHW: Last updated 0 days ago.
#
# Processing ALGN...
# Skipping ALGN: Last updated 0 days ago.
#
# Processing DXCM...
# Skipping DXCM: Last updated 0 days ago.
#
# Processing CME...
# Skipping CME: Last updated 0 days ago.
#
# Processing SPGI...
# Skipping SPGI: Last updated 0 days ago.
#
# Processing WM...
# Skipping WM: Last updated 0 days ago.
#
# Processing LIN...
# Skipping LIN: Last updated 0 days ago.
#
# Processing NOC...
# Skipping NOC: Last updated 0 days ago.
#
# Processing LYFT...
# Skipping LYFT: Last updated 0 days ago.
#
# Processing GOOS...
# Skipping GOOS: Last updated 0 days ago.
#
# Processing SE...
# Skipping SE: Last updated 0 days ago.
#
# Processing BIDU...
# Skipping BIDU: Last updated 0 days ago.
#
# Processing TJX...
# Skipping TJX: Last updated 0 days ago.
#
# Processing TGT...
# Skipping TGT: Last updated 0 days ago.
#
# Processing KKR...
# Skipping KKR: Last updated 0 days ago.
#
# Processing A...
# Skipping A: Last updated 0 days ago.
#
# Processing ON...
# Skipping ON: Last updated 0 days ago.
#
# Processing SNAP...
# Skipping SNAP: Last updated 0 days ago.
#
# Processing DHR...
# Skipping DHR: Last updated 0 days ago.
#
# Processing BTU...
# Skipping BTU: Growth Rate is negative.
#
# Processing CENX...
# Skipping CENX: Last updated 0 days ago.
#
# Processing AA...
# Skipping AA: Growth Rate is negative.
#
# Processing SCCO...
# Skipping SCCO: Last updated 0 days ago.
#
# Processing TGB...
# Skipping TGB: Last updated 0 days ago.
#
# Processing BKR...
# Skipping BKR: Last updated 0 days ago.
#
# Processing SLB...
# Skipping SLB: Last updated 0 days ago.
#
# Processing ZIM...
# Skipping ZIM: Last updated 0 days ago.
#
# Processing NEM...
# Skipping NEM: Last updated 0 days ago.
#
# Processing IAG...
# Skipping IAG: Last updated 0 days ago.
#
# Processing MCHP...
# Skipping MCHP: Last updated 0 days ago.
#
# Processing PBI...
# Skipping PBI: Last updated 0 days ago.
#
# Processing KGC...
# Skipping KGC: Last updated 0 days ago.
#
# Processing VIRT...
# Skipping VIRT: Last updated 0 days ago.
#
# Processing ALL...
# Skipping ALL: Last updated 0 days ago.
#
# Processing MFC...
# Skipping MFC: Last updated 0 days ago.
#
# Processing VEON...
# Skipping VEON: Last updated 0 days ago.
#
# Processing EGO...
# Skipping EGO: Last updated 0 days ago.
#
# Processing NGD...
# Skipping NGD: Last updated 0 days ago.
#
# Processing PAAS...
# Skipping PAAS: Last updated 0 days ago.
#
# Processing SVM...
# Skipping SVM: Last updated 0 days ago.
#
# Processing GLDD...
# Skipping GLDD: Last updated 0 days ago.
#
# Processing ET...
# Skipping ET: Last updated 0 days ago.
#
# Processing MPLX...
# Skipping MPLX: Last updated 0 days ago.
#
# Processing TRGP...
# Skipping TRGP: Last updated 0 days ago.
#
# Processing WES...
# Skipping WES: Last updated 0 days ago.
#
# Processing EPD...
# Skipping EPD: Last updated 0 days ago.
#
# Processing KMI...
# Skipping KMI: Last updated 0 days ago.
#
# Processing APO...
# Skipping APO: Last updated 0 days ago.
#
# Processing WBS...
# Skipping WBS: Last updated 0 days ago.
#
# Processing EWBC...
# Skipping EWBC: Last updated 0 days ago.
#
# Processing SO...
# Skipping SO: Last updated 0 days ago.
#
# Processing SKYW...
# Skipping SKYW: Last updated 0 days ago.
#
# Processing MCY...
# Skipping MCY: Last updated 0 days ago.
#
# Processing VIST...
# Skipping VIST: Last updated 0 days ago.
#
# Processing TS...
# Skipping TS: Last updated 0 days ago.
#
# Processing JD...
# Skipping JD: Last updated 0 days ago.
#
# Processing BABA...
# Skipping BABA: Last updated 0 days ago.
#
# Processing SWKS...
# Skipping SWKS: Last updated 0 days ago.
#
# Processing KRC...
# Skipping KRC: Last updated 0 days ago.
#
# Processing OXY...
# Skipping OXY: Last updated 0 days ago.
#
# Processing PPC...
# Skipping PPC: Last updated 0 days ago.
#
# Processing SMG...
# Skipping SMG: Last updated 0 days ago.
#
# Processing CTVA...
# Skipping CTVA: Last updated 0 days ago.
#
# Processing ADM...
# Skipping ADM: Last updated 0 days ago.
#
# Processing BG...
# Skipping BG: Growth Rate is negative.
#
# Processing DAR...
# Skipping DAR: Last updated 0 days ago.
#
# Processing INGR...
# Skipping INGR: Last updated 0 days ago.
#
# Processing CAG...
# Skipping CAG: Last updated 0 days ago.
#
# Processing KLG...
# Skipping KLG: Last updated 0 days ago.
#
# Processing KR...
# Skipping KR: Last updated 0 days ago.
#
# Processing ALEX...
# Skipping ALEX: Last updated 0 days ago.
#
# Processing LEN...
# Skipping LEN: Last updated 0 days ago.
#
# Processing TOL...
# Skipping TOL: Last updated 0 days ago.
#
# Processing TTWO...
# Skipping TTWO: Last updated 0 days ago.
#
# Processing HSY...
# Skipping HSY: Last updated 0 days ago.
#
# Processing CPAY...
# Skipping CPAY: Last updated 0 days ago.
#
# Processing ARM...
# Skipping ARM: Last updated 0 days ago.
#
# Processing ANET...
# Skipping ANET: Missing financial data.
#
# Processing PINS...
# Skipping PINS: Last updated 0 days ago.
#
# Processing MELI...
# Skipping MELI: Last updated 0 days ago.
#
# Processing MTCH...
# Skipping MTCH: Last updated 0 days ago.
#
# Processing ZTS...
# Skipping ZTS: Last updated 0 days ago.
#
# Processing TRIP...
# Skipping TRIP: Last updated 0 days ago.
#
# Processing NCLH...
# Skipping NCLH: Last updated 0 days ago.
#
# Processing SU...
# Skipping SU: Last updated 0 days ago.
#
# Processing NKE...
# Skipping NKE: Last updated 0 days ago.
#
# Processing SHEL...
# Skipping SHEL: Last updated 0 days ago.
#
# Processing IMO...
# Skipping IMO: Last updated 0 days ago.
#
# Processing PR...
# Skipping PR: Last updated 0 days ago.
#
# Processing CTRA...
# Skipping CTRA: Last updated 0 days ago.
#
# Processing NRG...
# Skipping NRG: Last updated 0 days ago.
#
# Processing COF...
# Skipping COF: Last updated 0 days ago.
#
# Processing DFS...
# Skipping DFS: Last updated 0 days ago.
#
# Processing COST...
# Skipping COST: Last updated 0 days ago.
#
# Processing LULU...
# Skipping LULU: Last updated 0 days ago.
#
# Processing SNOW...
# Skipping SNOW: Last updated 0 days ago.
#
# Processing ROST...
# Skipping ROST: Last updated 0 days ago.
#
# Processing PDD...
# Skipping PDD: Last updated 0 days ago.
#
# Processing XPEV...
# Skipping XPEV: Last updated 0 days ago.
#
# Processing NIO...
# Skipping NIO: Last updated 0 days ago.
#
# Processing COIN...
# Skipping COIN: Last updated 0 days ago.
#
# Processing CB...
# Skipping CB: Last updated 0 days ago.
#
# Processing ITW...
# Skipping ITW: Last updated 0 days ago.
#
# Processing CBOE...
# Skipping CBOE: Last updated 0 days ago.
#
# Processing DASH...
# Skipping DASH: Last updated 0 days ago.
#
# Processing MPWR...
# Skipping MPWR: Last updated 0 days ago.
#
# Processing ENB...
# Skipping ENB: Last updated 0 days ago.
#
# Processing FSLR...
# Skipping FSLR: Last updated 0 days ago.
#
# Processing LI...
# Skipping LI: Last updated 0 days ago.
#
# Processing LVS...
# Skipping LVS: Last updated 0 days ago.
#
# Processing AN...
# Skipping AN: Last updated 0 days ago.
#
# Processing NVO...
# Skipping NVO: Last updated 0 days ago.
#
# Processing SNPS...
# Skipping SNPS: Last updated 0 days ago.
#
# Processing CCI...
# Skipping CCI: Last updated 0 days ago.
#
# Processing STT...
# Skipping STT: Last updated 0 days ago.
#
# Processing CI...
# Skipping CI: Last updated 0 days ago.
#
# Processing CFLT...
# Skipping CFLT: Last updated 0 days ago.
#
# Processing TEAM...
# Skipping TEAM: Last updated 0 days ago.
#
# Processing FTK...
# Skipping FTK: Last updated 0 days ago.
#
# Processing SXT...
# Skipping SXT: Last updated 0 days ago.
#
# Processing IDXX...
# Skipping IDXX: Last updated 0 days ago.
#
# Processing AVGO...
# Skipping AVGO: Last updated 0 days ago.
#
# Processing FMS...
# Skipping FMS: Last updated 0 days ago.
#
# Processing DLTR...
# Skipping DLTR: Last updated 0 days ago.
#
# Processing MDB...
# Skipping MDB: Last updated 0 days ago.
#
# Processing EXEL...
# Skipping EXEL: Last updated 0 days ago.
#
# Processing DELL...
# Skipping DELL: Last updated 0 days ago.
#
# Processing BX...
# Skipping BX: Last updated 0 days ago.
#
# Processing FAST...
# Skipping FAST: Last updated 0 days ago.
#
# Processing DPZ...
# Skipping DPZ: Last updated 0 days ago.
#
# Processing ACN...
# Skipping ACN: Last updated 0 days ago.
#
# Processing DG...
# Skipping DG: Last updated 0 days ago.
#
# Processing ULTA...
# Skipping ULTA: Last updated 0 days ago.
#
# Processing RH...
# Skipping RH: Last updated 0 days ago.
#
# Processing DOCU...
# Skipping DOCU: Last updated 0 days ago.
#
# Processing CHWY...
# Skipping CHWY: Last updated 0 days ago.
#
# Processing KMX...
# Skipping KMX: Last updated 0 days ago.
#
# Processing M...
# Skipping M: Growth Rate is negative.
#
# Processing ADI...
# Skipping ADI: Last updated 0 days ago.
#
# Processing CSX...
# Skipping CSX: Last updated 0 days ago.
#
# Processing EQIX...
# Skipping EQIX: Last updated 0 days ago.
#
# Processing CNI...
# Skipping CNI: Last updated 0 days ago.
#
# Processing GILD...
# Skipping GILD: Last updated 0 days ago.
#
# Processing DD...
# Missing DCFDate for DD, recalculating.
#   TTM Free Cash Flow: 1240000000
#   Cash Equivalents: 2392000000
#   Total Debt: 7741000000
#   Shares Outstanding: 417955008
#   Projected Future Cash Flows (Years 1-10): [1388800000.0000002, 1555456000.0000005, 1742110720.0000007, 1951164006.400001, 2185303687.168001, 2250862797.7830415, 2318388681.7165327, 2387940342.168029, 2459578552.4330697, 2533365909.006062]
#   Terminal Value (TV): 52187337725.52488
#   Enterprise Value (EV): 37561855137.258896
# Next symbol to process: CRH
#
# Processing CRH...
# Skipping CRH: Last updated 0 days ago.
#
# Processing ECL...
# Missing DCFDate for ECL, recalculating.
#   TTM Free Cash Flow: 2002300000
#   Cash Equivalents: 919500000
#   Total Debt: 8733400000
#   Shares Outstanding: 283161984
#   Projected Future Cash Flows (Years 1-10): [2322668000.0, 2694294880.0, 3125382060.7999997, 3625443190.5279994, 4205514101.012479, 4373734665.0529785, 4548684051.655098, 4730631413.721302, 4919856670.270154, 5116650937.08096]
#   Terminal Value (TV): 105403009303.86777
#   Enterprise Value (EV): 74087843665.28809
# No more symbols to process.
# {'Symbol': 'DD', 'WACC': 8.0, 'Growth Rate (%)': 12.0, 'DCF Price': 77.0725425480699}
# {'Symbol': 'ECL', 'WACC': 8.0, 'Growth Rate (%)': 16.0, 'DCF Price': 234.04958084093693}
# DCF values successfully written back to the database.
